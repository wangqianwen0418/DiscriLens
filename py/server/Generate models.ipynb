# %%
import numpy as np
import pandas as pd
import os
import math

from pycausal.pycausal import pycausal as pc

import random
import re
import copy

from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import cross_val_score

# %%
foldername = "data"
filename = "credit_clean.csv"

sample_number = 5000
protected_attribute = 'sex'

# %%
data = pd.read_csv(foldername + '/' + filename)

print(data.dtypes)
# drop rows with any NA values
# Out:
# marriage                  object
# gender                    object
# checking_status           object
# duration                  object
# credit_history            object
# purpose                   object
# credit_amount             object
# savings_status            object
# employment                object
# installment_commitment     int64
# other_parties             object
# residence_since            int64
# property_magnitude        object
# age                       object
# other_payment_plans       object
# housing                   object
# existing_credits           int64
# job                       object
# num_dependents             int64
# own_telephone             object
# foreign_worker            object
# class                     object
# dtype: object

# %%
# Data generator
def find_range_cols(data):
        range_col = [] # columns that fit numerical values into ranges\
        for col in data.select_dtypes(exclude=['int64']).columns:
            if any(item in data[col][0] for item in ['>', '<']): 
                range_col.append(col)
        #print(range_col)
        return range_col
    
class DataGene(object):
    
    def __init__(self, data, sample_num=10, class_col='class'):
        self.data = data
        self.sample_num = sample_num
        self.class_col = 'class'
        
    def get_samples(self):
        features = self.data#.drop([self.class_col], axis=1)
        range_cols = find_range_cols(self.data)
        cat_cols = features.select_dtypes(exclude=['int64']).drop(range_cols, axis=1).columns
        num_cols = features.select_dtypes(include=['int64']).columns
        print(num_cols)
        output = []
        for var in num_cols:
            output.append(var)
        #print(type(output))
        samples = []
        
        for i in range(self.sample_num):
            sample_cat = [
                random.choice( list(set(features[cat_name])) )
                for cat_name in cat_cols
            ]
            sample_num = [
                random.choice( list(set(features[num_name])) )
                for num_name in num_cols
            ]
            sample_range = [
                random.choice( list(set(features[range_name])) )
                for range_name in range_cols
            ]
            sample = sample_cat + sample_num + sample_range
            samples.append(sample)
            
        
        samples = pd.DataFrame(samples, columns=list(cat_cols)+list(num_cols)+range_cols)
        return samples

# %%
# generate new samples
dataGene = DataGene(data, sample_num=sample_number)
new_samples = dataGene.get_samples()
new_samples
# encode sample data
#x_samples, y_samples = encoder.transform(new_samples)
# Out:
# Index(['installment_commitment', 'residence_since', 'existing_credits',
#        'num_dependents'],
#       dtype='object')
#          marriage  gender                  credit_history  \
# 0         mar/wid    male                        all paid
# 1         mar/wid    male                        all paid
# 2         mar/wid  female  critical/other existing credit
# 3         div/sep    male                   existing paid
# 4     div/dep/mar  female  critical/other existing credit
# 5          single    male  critical/other existing credit
# 6     div/dep/mar  female  critical/other existing credit
# 7     div/dep/mar  female                   existing paid
# 8          single    male  critical/other existing credit
# 9         div/sep  female  critical/other existing credit
# 10        div/sep  female  critical/other existing credit
# 11    div/dep/mar    male              delayed previously
# 12    div/dep/mar  female              delayed previously
# 13    div/dep/mar    male              delayed previously
# 14         single    male             no credits/all paid
# 15    div/dep/mar  female  critical/other existing credit
# 16        div/sep    male             no credits/all paid
# 17        mar/wid  female                   existing paid
# 18        div/sep    male              delayed previously
# 19        mar/wid    male             no credits/all paid
# 20        mar/wid  female             no credits/all paid
# 21        mar/wid  female              delayed previously
# 22         single  female  critical/other existing credit
# 23    div/dep/mar  female                   existing paid
# 24        div/sep    male                        all paid
# 25         single  female             no credits/all paid
# 26        div/sep    male              delayed previously
# 27        mar/wid  female                   existing paid
# 28    div/dep/mar    male                        all paid
# 29    div/dep/mar    male                        all paid
# ...           ...     ...                             ...
# 4970       single  female                   existing paid
# 4971  div/dep/mar  female                   existing paid
# 4972       single  female             no credits/all paid
# 4973       single    male              delayed previously
# 4974      div/sep    male                        all paid
# 4975       single    male  critical/other existing credit
# 4976       single    male                   existing paid
# 4977       single    male              delayed previously
# 4978  div/dep/mar  female  critical/other existing credit
# 4979  div/dep/mar    male                   existing paid
# 4980      mar/wid    male             no credits/all paid
# 4981  div/dep/mar  female                        all paid
# 4982       single    male                   existing paid
# 4983      mar/wid  female              delayed previously
# 4984  div/dep/mar  female                        all paid
# 4985      div/sep    male                   existing paid
# 4986      div/sep  female             no credits/all paid
# 4987  div/dep/mar  female                        all paid
# 4988      div/sep  female             no credits/all paid
# 4989  div/dep/mar  female              delayed previously
# 4990      div/sep  female             no credits/all paid
# 4991      mar/wid    male                        all paid
# 4992      mar/wid  female                   existing paid
# 4993       single  female             no credits/all paid
# 4994  div/dep/mar    male  critical/other existing credit
# 4995      mar/wid  female                   existing paid
# 4996      mar/wid  female  critical/other existing credit
# 4997      mar/wid  female              delayed previously
# 4998  div/dep/mar    male  critical/other existing credit
# 4999      mar/wid  female              delayed previously
#
#                   purpose    savings_status other_parties property_magnitude  \
# 0                 new car            >=1000     guarantor  no known property
# 1                used car        100<=X<500          none     life insurance
# 2                radio/tv       500<=X<1000     guarantor        real estate
# 3                used car       500<=X<1000  co applicant                car
# 4                used car       500<=X<1000  co applicant        real estate
# 5      domestic appliance            >=1000  co applicant     life insurance
# 6              retraining              <100  co applicant  no known property
# 7                   other  no known savings  co applicant                car
# 8                used car            >=1000          none  no known property
# 9                 new car        100<=X<500          none     life insurance
# 10     domestic appliance              <100     guarantor        real estate
# 11              education        100<=X<500          none        real estate
# 12                  other  no known savings  co applicant        real estate
# 13               radio/tv            >=1000          none     life insurance
# 14               business            >=1000  co applicant     life insurance
# 15               radio/tv  no known savings     guarantor  no known property
# 16                new car            >=1000          none  no known property
# 17               business       500<=X<1000  co applicant     life insurance
# 18               business       500<=X<1000          none     life insurance
# 19     domestic appliance       500<=X<1000  co applicant  no known property
# 20    furniture/equipment            >=1000  co applicant     life insurance
# 21     domestic appliance  no known savings     guarantor     life insurance
# 22               used car  no known savings     guarantor  no known property
# 23                new car            >=1000  co applicant                car
# 24             retraining       500<=X<1000     guarantor  no known property
# 25                repairs        100<=X<500     guarantor                car
# 26              education              <100          none                car
# 27               business        100<=X<500     guarantor                car
# 28              education       500<=X<1000     guarantor  no known property
# 29                new car        100<=X<500  co applicant        real estate
# ...                   ...               ...           ...                ...
# 4970             used car       500<=X<1000          none  no known property
# 4971              repairs       500<=X<1000     guarantor     life insurance
# 4972  furniture/equipment       500<=X<1000     guarantor  no known property
# 4973             used car              <100  co applicant  no known property
# 4974           retraining  no known savings  co applicant  no known property
# 4975             used car        100<=X<500  co applicant                car
# 4976             used car        100<=X<500     guarantor     life insurance
# 4977  furniture/equipment            >=1000  co applicant                car
# 4978            education  no known savings  co applicant                car
# 4979              new car            >=1000     guarantor                car
# 4980             used car            >=1000  co applicant        real estate
# 4981             used car  no known savings  co applicant                car
# 4982             radio/tv  no known savings          none                car
# 4983             used car              <100     guarantor  no known property
# 4984                other              <100  co applicant                car
# 4985             business       500<=X<1000  co applicant        real estate
# 4986   domestic appliance        100<=X<500          none        real estate
# 4987                other       500<=X<1000          none  no known property
# 4988             used car        100<=X<500     guarantor     life insurance
# 4989   domestic appliance        100<=X<500  co applicant  no known property
# 4990   domestic appliance        100<=X<500  co applicant  no known property
# 4991  furniture/equipment              <100  co applicant     life insurance
# 4992  furniture/equipment  no known savings  co applicant     life insurance
# 4993             radio/tv       500<=X<1000     guarantor  no known property
# 4994             radio/tv       500<=X<1000     guarantor     life insurance
# 4995   domestic appliance              <100          none        real estate
# 4996  furniture/equipment  no known savings  co applicant     life insurance
# 4997             used car  no known savings          none  no known property
# 4998             radio/tv              <100     guarantor     life insurance
# 4999              repairs              <100          none                car
#
#      other_payment_plans   housing                        job   ...    class  \
# 0                 stores  for free                    skilled   ...     good
# 1                   bank  for free  high qualif/self emp/mgmt   ...     good
# 2                 stores  for free         unskilled resident   ...     good
# 3                   bank       own                    skilled   ...     good
# 4                 stores  for free         unskilled resident   ...      bad
# 5                 stores       own         unskilled resident   ...     good
# 6                 stores       own  high qualif/self emp/mgmt   ...      bad
# 7                   none  for free                    skilled   ...     good
# 8                   bank  for free         unskilled resident   ...      bad
# 9                   bank       own    unemp/unskilled non res   ...      bad
# 10                  bank      rent  high qualif/self emp/mgmt   ...      bad
# 11                stores       own         unskilled resident   ...      bad
# 12                  none       own         unskilled resident   ...     good
# 13                  bank       own  high qualif/self emp/mgmt   ...     good
# 14                  none  for free    unemp/unskilled non res   ...      bad
# 15                  bank  for free    unemp/unskilled non res   ...      bad
# 16                  none  for free         unskilled resident   ...     good
# 17                stores       own    unemp/unskilled non res   ...      bad
# 18                  bank      rent         unskilled resident   ...      bad
# 19                  bank      rent    unemp/unskilled non res   ...      bad
# 20                  bank       own                    skilled   ...     good
# 21                stores       own         unskilled resident   ...     good
# 22                stores  for free  high qualif/self emp/mgmt   ...     good
# 23                  none  for free                    skilled   ...     good
# 24                stores      rent                    skilled   ...     good
# 25                  none  for free  high qualif/self emp/mgmt   ...      bad
# 26                  none       own  high qualif/self emp/mgmt   ...      bad
# 27                  bank       own    unemp/unskilled non res   ...      bad
# 28                stores       own  high qualif/self emp/mgmt   ...     good
# 29                stores      rent    unemp/unskilled non res   ...     good
# ...                  ...       ...                        ...   ...      ...
# 4970              stores      rent    unemp/unskilled non res   ...     good
# 4971                none       own  high qualif/self emp/mgmt   ...      bad
# 4972              stores      rent  high qualif/self emp/mgmt   ...     good
# 4973                bank  for free    unemp/unskilled non res   ...      bad
# 4974              stores  for free                    skilled   ...     good
# 4975                none      rent  high qualif/self emp/mgmt   ...      bad
# 4976                bank  for free    unemp/unskilled non res   ...      bad
# 4977              stores  for free         unskilled resident   ...     good
# 4978                none  for free    unemp/unskilled non res   ...     good
# 4979              stores       own         unskilled resident   ...     good
# 4980                bank      rent    unemp/unskilled non res   ...     good
# 4981                bank      rent  high qualif/self emp/mgmt   ...     good
# 4982                none      rent    unemp/unskilled non res   ...     good
# 4983                bank      rent                    skilled   ...      bad
# 4984              stores       own    unemp/unskilled non res   ...     good
# 4985              stores      rent  high qualif/self emp/mgmt   ...     good
# 4986              stores       own    unemp/unskilled non res   ...     good
# 4987                bank      rent  high qualif/self emp/mgmt   ...     good
# 4988                bank  for free  high qualif/self emp/mgmt   ...     good
# 4989                none      rent         unskilled resident   ...     good
# 4990              stores  for free  high qualif/self emp/mgmt   ...      bad
# 4991              stores       own  high qualif/self emp/mgmt   ...     good
# 4992                none      rent                    skilled   ...      bad
# 4993                none  for free                    skilled   ...     good
# 4994                none       own  high qualif/self emp/mgmt   ...      bad
# 4995                bank       own                    skilled   ...     good
# 4996                bank  for free  high qualif/self emp/mgmt   ...      bad
# 4997                none       own         unskilled resident   ...      bad
# 4998                bank       own                    skilled   ...      bad
# 4999                none      rent    unemp/unskilled non res   ...     good
#
#      installment_commitment residence_since  existing_credits  num_dependents  \
# 0                         1               1                 1               1
# 1                         1               1                 2               1
# 2                         2               1                 3               2
# 3                         4               4                 3               1
# 4                         2               1                 2               1
# 5                         2               2                 4               1
# 6                         1               2                 1               2
# 7                         2               4                 3               2
# 8                         4               2                 2               1
# 9                         1               1                 4               2
# 10                        3               4                 4               1
# 11                        4               1                 1               1
# 12                        1               4                 2               1
# 13                        4               1                 4               2
# 14                        1               1                 3               2
# 15                        3               4                 3               1
# 16                        1               3                 3               1
# 17                        4               3                 1               2
# 18                        4               2                 1               1
# 19                        3               1                 1               1
# 20                        1               1                 1               1
# 21                        1               4                 4               1
# 22                        3               4                 3               2
# 23                        2               1                 1               1
# 24                        1               4                 3               1
# 25                        4               2                 2               2
# 26                        4               2                 4               1
# 27                        2               4                 3               1
# 28                        1               4                 3               1
# 29                        1               3                 4               2
# ...                     ...             ...               ...             ...
# 4970                      1               3                 4               1
# 4971                      2               3                 1               2
# 4972                      3               3                 3               2
# 4973                      2               1                 1               1
# 4974                      2               1                 2               1
# 4975                      2               4                 1               2
# 4976                      2               1                 4               1
# 4977                      2               2                 3               2
# 4978                      2               4                 3               1
# 4979                      2               4                 1               1
# 4980                      3               3                 3               1
# 4981                      3               3                 2               2
# 4982                      2               2                 3               1
# 4983                      4               3                 3               1
# 4984                      1               4                 1               1
# 4985                      2               1                 2               1
# 4986                      1               4                 1               1
# 4987                      2               2                 2               2
# 4988                      1               1                 1               2
# 4989                      4               2                 4               1
# 4990                      2               4                 4               2
# 4991                      2               1                 3               1
# 4992                      4               4                 3               1
# 4993                      1               2                 2               2
# 4994                      1               1                 4               2
# 4995                      3               2                 3               2
# 4996                      2               4                 3               2
# 4997                      1               3                 2               2
# 4998                      3               3                 2               1
# 4999                      3               4                 1               1
#
#       checking_status  duration credit_amount  employment      age
# 0               >=200       x<4  9337<x<13880         >=7  47<x<61
# 1         no checking   21<x<38   4793<x<9337          <1  47<x<61
# 2               >=200   38<x<55         x<250         >=7  47<x<61
# 3               >=200      x>55         x<250          <1     x>61
# 4            0<=X<200    4<x<21  9337<x<13880      1<=X<4     x<19
# 5               >=200      x>55  9337<x<13880         >=7  33<x<47
# 6               >=200    4<x<21   4793<x<9337      4<=X<7     x>61
# 7         no checking      x>55       x>13880      1<=X<4     x>61
# 8         no checking   38<x<55         x<250      1<=X<4     x>61
# 9            0<=X<200   21<x<38    250<x<4793  unemployed  47<x<61
# 10              >=200      x>55    250<x<4793         >=7     x<19
# 11                 <0       x<4         x<250          <1  33<x<47
# 12                 <0      x>55   4793<x<9337         >=7  19<x<33
# 13           0<=X<200       x<4       x>13880         >=7  19<x<33
# 14                 <0       x<4  9337<x<13880      4<=X<7  47<x<61
# 15           0<=X<200    4<x<21       x>13880  unemployed  47<x<61
# 16           0<=X<200    4<x<21   4793<x<9337  unemployed  47<x<61
# 17                 <0    4<x<21   4793<x<9337          <1     x>61
# 18           0<=X<200   21<x<38       x>13880         >=7  33<x<47
# 19              >=200      x>55       x>13880          <1  33<x<47
# 20              >=200       x<4       x>13880  unemployed  33<x<47
# 21           0<=X<200      x>55  9337<x<13880      1<=X<4     x<19
# 22                 <0    4<x<21  9337<x<13880      4<=X<7  33<x<47
# 23              >=200      x>55       x>13880      1<=X<4     x>61
# 24           0<=X<200   21<x<38    250<x<4793      4<=X<7  19<x<33
# 25           0<=X<200       x<4   4793<x<9337  unemployed     x<19
# 26           0<=X<200       x<4  9337<x<13880         >=7  19<x<33
# 27           0<=X<200      x>55   4793<x<9337         >=7     x>61
# 28        no checking      x>55    250<x<4793  unemployed  33<x<47
# 29              >=200    4<x<21         x<250      4<=X<7     x<19
# ...               ...       ...           ...         ...      ...
# 4970               <0      x>55  9337<x<13880      1<=X<4  33<x<47
# 4971         0<=X<200   21<x<38    250<x<4793      4<=X<7  47<x<61
# 4972               <0       x<4       x>13880         >=7     x<19
# 4973         0<=X<200       x<4  9337<x<13880      4<=X<7  19<x<33
# 4974         0<=X<200   21<x<38       x>13880          <1  19<x<33
# 4975               <0       x<4   4793<x<9337          <1  47<x<61
# 4976         0<=X<200    4<x<21  9337<x<13880         >=7  33<x<47
# 4977               <0   21<x<38  9337<x<13880      4<=X<7  33<x<47
# 4978      no checking    4<x<21   4793<x<9337      1<=X<4     x<19
# 4979         0<=X<200       x<4   4793<x<9337  unemployed     x<19
# 4980            >=200      x>55    250<x<4793  unemployed  47<x<61
# 4981               <0   21<x<38   4793<x<9337      1<=X<4     x<19
# 4982            >=200       x<4       x>13880  unemployed  19<x<33
# 4983      no checking   38<x<55         x<250          <1     x>61
# 4984               <0   38<x<55    250<x<4793  unemployed     x<19
# 4985            >=200       x<4   4793<x<9337          <1     x<19
# 4986            >=200      x>55  9337<x<13880      1<=X<4  19<x<33
# 4987               <0   21<x<38    250<x<4793      4<=X<7     x<19
# 4988               <0       x<4    250<x<4793         >=7     x>61
# 4989         0<=X<200      x>55         x<250      4<=X<7  33<x<47
# 4990      no checking   21<x<38         x<250      1<=X<4     x<19
# 4991               <0   38<x<55         x<250  unemployed     x<19
# 4992         0<=X<200    4<x<21   4793<x<9337         >=7  47<x<61
# 4993         0<=X<200       x<4       x>13880      4<=X<7  19<x<33
# 4994         0<=X<200   38<x<55         x<250         >=7     x>61
# 4995               <0    4<x<21  9337<x<13880      4<=X<7  33<x<47
# 4996            >=200       x<4   4793<x<9337      1<=X<4     x<19
# 4997            >=200   38<x<55   4793<x<9337  unemployed  19<x<33
# 4998         0<=X<200      x>55    250<x<4793      1<=X<4     x<19
# 4999            >=200    4<x<21  9337<x<13880      1<=X<4  47<x<61
#
# [5000 rows x 22 columns]

# %%
import pandas as pd
import os
from collections import OrderedDict
import math





def findRange(thresholds, v):
    for i, th in enumerate(thresholds):
        if(v <= th):
            if i==0:
                return "x<{}".format(th)
            elif i == len(thresholds)-1:
                return "x>{}".format(thresholds[i-1])
            else:
                return "{}<x<{}".format(thresholds[i-1], thresholds[i])

def convert_cate(arr):
    n = 4 #parts to be divided
    maxValue = max(arr)
    minValue = min(arr)
    thresholds = [ math.floor(i*(maxValue-minValue)/n)+minValue for i in range(n+1)]

    #print([findRange(thresholds, i) for i in arr])
    
    return pd.Series([findRange(thresholds, i) for i in arr])


def num2cate(dataIn):
    dfc = dataIn[:]
#     new_data = pd.DataFrame()
    for k in dfc.columns:
        if(k in dfc.select_dtypes(include=['int64'])):
            values = pd.to_numeric(dfc[k])
            dfc[k] = convert_cate(values.tolist())
        
    return dfc

# num to cate
new_samples = num2cate(new_samples)
new_samples
# Out:
#          marriage  gender                  credit_history  \
# 0         mar/wid    male                        all paid
# 1         mar/wid    male                        all paid
# 2         mar/wid  female  critical/other existing credit
# 3         div/sep    male                   existing paid
# 4     div/dep/mar  female  critical/other existing credit
# 5          single    male  critical/other existing credit
# 6     div/dep/mar  female  critical/other existing credit
# 7     div/dep/mar  female                   existing paid
# 8          single    male  critical/other existing credit
# 9         div/sep  female  critical/other existing credit
# 10        div/sep  female  critical/other existing credit
# 11    div/dep/mar    male              delayed previously
# 12    div/dep/mar  female              delayed previously
# 13    div/dep/mar    male              delayed previously
# 14         single    male             no credits/all paid
# 15    div/dep/mar  female  critical/other existing credit
# 16        div/sep    male             no credits/all paid
# 17        mar/wid  female                   existing paid
# 18        div/sep    male              delayed previously
# 19        mar/wid    male             no credits/all paid
# 20        mar/wid  female             no credits/all paid
# 21        mar/wid  female              delayed previously
# 22         single  female  critical/other existing credit
# 23    div/dep/mar  female                   existing paid
# 24        div/sep    male                        all paid
# 25         single  female             no credits/all paid
# 26        div/sep    male              delayed previously
# 27        mar/wid  female                   existing paid
# 28    div/dep/mar    male                        all paid
# 29    div/dep/mar    male                        all paid
# ...           ...     ...                             ...
# 4970       single  female                   existing paid
# 4971  div/dep/mar  female                   existing paid
# 4972       single  female             no credits/all paid
# 4973       single    male              delayed previously
# 4974      div/sep    male                        all paid
# 4975       single    male  critical/other existing credit
# 4976       single    male                   existing paid
# 4977       single    male              delayed previously
# 4978  div/dep/mar  female  critical/other existing credit
# 4979  div/dep/mar    male                   existing paid
# 4980      mar/wid    male             no credits/all paid
# 4981  div/dep/mar  female                        all paid
# 4982       single    male                   existing paid
# 4983      mar/wid  female              delayed previously
# 4984  div/dep/mar  female                        all paid
# 4985      div/sep    male                   existing paid
# 4986      div/sep  female             no credits/all paid
# 4987  div/dep/mar  female                        all paid
# 4988      div/sep  female             no credits/all paid
# 4989  div/dep/mar  female              delayed previously
# 4990      div/sep  female             no credits/all paid
# 4991      mar/wid    male                        all paid
# 4992      mar/wid  female                   existing paid
# 4993       single  female             no credits/all paid
# 4994  div/dep/mar    male  critical/other existing credit
# 4995      mar/wid  female                   existing paid
# 4996      mar/wid  female  critical/other existing credit
# 4997      mar/wid  female              delayed previously
# 4998  div/dep/mar    male  critical/other existing credit
# 4999      mar/wid  female              delayed previously
#
#                   purpose    savings_status other_parties property_magnitude  \
# 0                 new car            >=1000     guarantor  no known property
# 1                used car        100<=X<500          none     life insurance
# 2                radio/tv       500<=X<1000     guarantor        real estate
# 3                used car       500<=X<1000  co applicant                car
# 4                used car       500<=X<1000  co applicant        real estate
# 5      domestic appliance            >=1000  co applicant     life insurance
# 6              retraining              <100  co applicant  no known property
# 7                   other  no known savings  co applicant                car
# 8                used car            >=1000          none  no known property
# 9                 new car        100<=X<500          none     life insurance
# 10     domestic appliance              <100     guarantor        real estate
# 11              education        100<=X<500          none        real estate
# 12                  other  no known savings  co applicant        real estate
# 13               radio/tv            >=1000          none     life insurance
# 14               business            >=1000  co applicant     life insurance
# 15               radio/tv  no known savings     guarantor  no known property
# 16                new car            >=1000          none  no known property
# 17               business       500<=X<1000  co applicant     life insurance
# 18               business       500<=X<1000          none     life insurance
# 19     domestic appliance       500<=X<1000  co applicant  no known property
# 20    furniture/equipment            >=1000  co applicant     life insurance
# 21     domestic appliance  no known savings     guarantor     life insurance
# 22               used car  no known savings     guarantor  no known property
# 23                new car            >=1000  co applicant                car
# 24             retraining       500<=X<1000     guarantor  no known property
# 25                repairs        100<=X<500     guarantor                car
# 26              education              <100          none                car
# 27               business        100<=X<500     guarantor                car
# 28              education       500<=X<1000     guarantor  no known property
# 29                new car        100<=X<500  co applicant        real estate
# ...                   ...               ...           ...                ...
# 4970             used car       500<=X<1000          none  no known property
# 4971              repairs       500<=X<1000     guarantor     life insurance
# 4972  furniture/equipment       500<=X<1000     guarantor  no known property
# 4973             used car              <100  co applicant  no known property
# 4974           retraining  no known savings  co applicant  no known property
# 4975             used car        100<=X<500  co applicant                car
# 4976             used car        100<=X<500     guarantor     life insurance
# 4977  furniture/equipment            >=1000  co applicant                car
# 4978            education  no known savings  co applicant                car
# 4979              new car            >=1000     guarantor                car
# 4980             used car            >=1000  co applicant        real estate
# 4981             used car  no known savings  co applicant                car
# 4982             radio/tv  no known savings          none                car
# 4983             used car              <100     guarantor  no known property
# 4984                other              <100  co applicant                car
# 4985             business       500<=X<1000  co applicant        real estate
# 4986   domestic appliance        100<=X<500          none        real estate
# 4987                other       500<=X<1000          none  no known property
# 4988             used car        100<=X<500     guarantor     life insurance
# 4989   domestic appliance        100<=X<500  co applicant  no known property
# 4990   domestic appliance        100<=X<500  co applicant  no known property
# 4991  furniture/equipment              <100  co applicant     life insurance
# 4992  furniture/equipment  no known savings  co applicant     life insurance
# 4993             radio/tv       500<=X<1000     guarantor  no known property
# 4994             radio/tv       500<=X<1000     guarantor     life insurance
# 4995   domestic appliance              <100          none        real estate
# 4996  furniture/equipment  no known savings  co applicant     life insurance
# 4997             used car  no known savings          none  no known property
# 4998             radio/tv              <100     guarantor     life insurance
# 4999              repairs              <100          none                car
#
#      other_payment_plans   housing                        job   ...    class  \
# 0                 stores  for free                    skilled   ...     good
# 1                   bank  for free  high qualif/self emp/mgmt   ...     good
# 2                 stores  for free         unskilled resident   ...     good
# 3                   bank       own                    skilled   ...     good
# 4                 stores  for free         unskilled resident   ...      bad
# 5                 stores       own         unskilled resident   ...     good
# 6                 stores       own  high qualif/self emp/mgmt   ...      bad
# 7                   none  for free                    skilled   ...     good
# 8                   bank  for free         unskilled resident   ...      bad
# 9                   bank       own    unemp/unskilled non res   ...      bad
# 10                  bank      rent  high qualif/self emp/mgmt   ...      bad
# 11                stores       own         unskilled resident   ...      bad
# 12                  none       own         unskilled resident   ...     good
# 13                  bank       own  high qualif/self emp/mgmt   ...     good
# 14                  none  for free    unemp/unskilled non res   ...      bad
# 15                  bank  for free    unemp/unskilled non res   ...      bad
# 16                  none  for free         unskilled resident   ...     good
# 17                stores       own    unemp/unskilled non res   ...      bad
# 18                  bank      rent         unskilled resident   ...      bad
# 19                  bank      rent    unemp/unskilled non res   ...      bad
# 20                  bank       own                    skilled   ...     good
# 21                stores       own         unskilled resident   ...     good
# 22                stores  for free  high qualif/self emp/mgmt   ...     good
# 23                  none  for free                    skilled   ...     good
# 24                stores      rent                    skilled   ...     good
# 25                  none  for free  high qualif/self emp/mgmt   ...      bad
# 26                  none       own  high qualif/self emp/mgmt   ...      bad
# 27                  bank       own    unemp/unskilled non res   ...      bad
# 28                stores       own  high qualif/self emp/mgmt   ...     good
# 29                stores      rent    unemp/unskilled non res   ...     good
# ...                  ...       ...                        ...   ...      ...
# 4970              stores      rent    unemp/unskilled non res   ...     good
# 4971                none       own  high qualif/self emp/mgmt   ...      bad
# 4972              stores      rent  high qualif/self emp/mgmt   ...     good
# 4973                bank  for free    unemp/unskilled non res   ...      bad
# 4974              stores  for free                    skilled   ...     good
# 4975                none      rent  high qualif/self emp/mgmt   ...      bad
# 4976                bank  for free    unemp/unskilled non res   ...      bad
# 4977              stores  for free         unskilled resident   ...     good
# 4978                none  for free    unemp/unskilled non res   ...     good
# 4979              stores       own         unskilled resident   ...     good
# 4980                bank      rent    unemp/unskilled non res   ...     good
# 4981                bank      rent  high qualif/self emp/mgmt   ...     good
# 4982                none      rent    unemp/unskilled non res   ...     good
# 4983                bank      rent                    skilled   ...      bad
# 4984              stores       own    unemp/unskilled non res   ...     good
# 4985              stores      rent  high qualif/self emp/mgmt   ...     good
# 4986              stores       own    unemp/unskilled non res   ...     good
# 4987                bank      rent  high qualif/self emp/mgmt   ...     good
# 4988                bank  for free  high qualif/self emp/mgmt   ...     good
# 4989                none      rent         unskilled resident   ...     good
# 4990              stores  for free  high qualif/self emp/mgmt   ...      bad
# 4991              stores       own  high qualif/self emp/mgmt   ...     good
# 4992                none      rent                    skilled   ...      bad
# 4993                none  for free                    skilled   ...     good
# 4994                none       own  high qualif/self emp/mgmt   ...      bad
# 4995                bank       own                    skilled   ...     good
# 4996                bank  for free  high qualif/self emp/mgmt   ...      bad
# 4997                none       own         unskilled resident   ...      bad
# 4998                bank       own                    skilled   ...      bad
# 4999                none      rent    unemp/unskilled non res   ...     good
#
#      installment_commitment residence_since existing_credits num_dependents  \
# 0                       x<1             x<1              x<1            x<1
# 1                       x<1             x<1            1<x<2            x<1
# 2                     1<x<2             x<1            2<x<3            x>1
# 3                       x>3             x>3            2<x<3            x<1
# 4                     1<x<2             x<1            1<x<2            x<1
# 5                     1<x<2           1<x<2              x>3            x<1
# 6                       x<1           1<x<2              x<1            x>1
# 7                     1<x<2             x>3            2<x<3            x>1
# 8                       x>3           1<x<2            1<x<2            x<1
# 9                       x<1             x<1              x>3            x>1
# 10                    2<x<3             x>3              x>3            x<1
# 11                      x>3             x<1              x<1            x<1
# 12                      x<1             x>3            1<x<2            x<1
# 13                      x>3             x<1              x>3            x>1
# 14                      x<1             x<1            2<x<3            x>1
# 15                    2<x<3             x>3            2<x<3            x<1
# 16                      x<1           2<x<3            2<x<3            x<1
# 17                      x>3           2<x<3              x<1            x>1
# 18                      x>3           1<x<2              x<1            x<1
# 19                    2<x<3             x<1              x<1            x<1
# 20                      x<1             x<1              x<1            x<1
# 21                      x<1             x>3              x>3            x<1
# 22                    2<x<3             x>3            2<x<3            x>1
# 23                    1<x<2             x<1              x<1            x<1
# 24                      x<1             x>3            2<x<3            x<1
# 25                      x>3           1<x<2            1<x<2            x>1
# 26                      x>3           1<x<2              x>3            x<1
# 27                    1<x<2             x>3            2<x<3            x<1
# 28                      x<1             x>3            2<x<3            x<1
# 29                      x<1           2<x<3              x>3            x>1
# ...                     ...             ...              ...            ...
# 4970                    x<1           2<x<3              x>3            x<1
# 4971                  1<x<2           2<x<3              x<1            x>1
# 4972                  2<x<3           2<x<3            2<x<3            x>1
# 4973                  1<x<2             x<1              x<1            x<1
# 4974                  1<x<2             x<1            1<x<2            x<1
# 4975                  1<x<2             x>3              x<1            x>1
# 4976                  1<x<2             x<1              x>3            x<1
# 4977                  1<x<2           1<x<2            2<x<3            x>1
# 4978                  1<x<2             x>3            2<x<3            x<1
# 4979                  1<x<2             x>3              x<1            x<1
# 4980                  2<x<3           2<x<3            2<x<3            x<1
# 4981                  2<x<3           2<x<3            1<x<2            x>1
# 4982                  1<x<2           1<x<2            2<x<3            x<1
# 4983                    x>3           2<x<3            2<x<3            x<1
# 4984                    x<1             x>3              x<1            x<1
# 4985                  1<x<2             x<1            1<x<2            x<1
# 4986                    x<1             x>3              x<1            x<1
# 4987                  1<x<2           1<x<2            1<x<2            x>1
# 4988                    x<1             x<1              x<1            x>1
# 4989                    x>3           1<x<2              x>3            x<1
# 4990                  1<x<2             x>3              x>3            x>1
# 4991                  1<x<2             x<1            2<x<3            x<1
# 4992                    x>3             x>3            2<x<3            x<1
# 4993                    x<1           1<x<2            1<x<2            x>1
# 4994                    x<1             x<1              x>3            x>1
# 4995                  2<x<3           1<x<2            2<x<3            x>1
# 4996                  1<x<2             x>3            2<x<3            x>1
# 4997                    x<1           2<x<3            1<x<2            x>1
# 4998                  2<x<3           2<x<3            1<x<2            x<1
# 4999                  2<x<3             x>3              x<1            x<1
#
#      checking_status duration credit_amount  employment      age
# 0              >=200      x<4  9337<x<13880         >=7  47<x<61
# 1        no checking  21<x<38   4793<x<9337          <1  47<x<61
# 2              >=200  38<x<55         x<250         >=7  47<x<61
# 3              >=200     x>55         x<250          <1     x>61
# 4           0<=X<200   4<x<21  9337<x<13880      1<=X<4     x<19
# 5              >=200     x>55  9337<x<13880         >=7  33<x<47
# 6              >=200   4<x<21   4793<x<9337      4<=X<7     x>61
# 7        no checking     x>55       x>13880      1<=X<4     x>61
# 8        no checking  38<x<55         x<250      1<=X<4     x>61
# 9           0<=X<200  21<x<38    250<x<4793  unemployed  47<x<61
# 10             >=200     x>55    250<x<4793         >=7     x<19
# 11                <0      x<4         x<250          <1  33<x<47
# 12                <0     x>55   4793<x<9337         >=7  19<x<33
# 13          0<=X<200      x<4       x>13880         >=7  19<x<33
# 14                <0      x<4  9337<x<13880      4<=X<7  47<x<61
# 15          0<=X<200   4<x<21       x>13880  unemployed  47<x<61
# 16          0<=X<200   4<x<21   4793<x<9337  unemployed  47<x<61
# 17                <0   4<x<21   4793<x<9337          <1     x>61
# 18          0<=X<200  21<x<38       x>13880         >=7  33<x<47
# 19             >=200     x>55       x>13880          <1  33<x<47
# 20             >=200      x<4       x>13880  unemployed  33<x<47
# 21          0<=X<200     x>55  9337<x<13880      1<=X<4     x<19
# 22                <0   4<x<21  9337<x<13880      4<=X<7  33<x<47
# 23             >=200     x>55       x>13880      1<=X<4     x>61
# 24          0<=X<200  21<x<38    250<x<4793      4<=X<7  19<x<33
# 25          0<=X<200      x<4   4793<x<9337  unemployed     x<19
# 26          0<=X<200      x<4  9337<x<13880         >=7  19<x<33
# 27          0<=X<200     x>55   4793<x<9337         >=7     x>61
# 28       no checking     x>55    250<x<4793  unemployed  33<x<47
# 29             >=200   4<x<21         x<250      4<=X<7     x<19
# ...              ...      ...           ...         ...      ...
# 4970              <0     x>55  9337<x<13880      1<=X<4  33<x<47
# 4971        0<=X<200  21<x<38    250<x<4793      4<=X<7  47<x<61
# 4972              <0      x<4       x>13880         >=7     x<19
# 4973        0<=X<200      x<4  9337<x<13880      4<=X<7  19<x<33
# 4974        0<=X<200  21<x<38       x>13880          <1  19<x<33
# 4975              <0      x<4   4793<x<9337          <1  47<x<61
# 4976        0<=X<200   4<x<21  9337<x<13880         >=7  33<x<47
# 4977              <0  21<x<38  9337<x<13880      4<=X<7  33<x<47
# 4978     no checking   4<x<21   4793<x<9337      1<=X<4     x<19
# 4979        0<=X<200      x<4   4793<x<9337  unemployed     x<19
# 4980           >=200     x>55    250<x<4793  unemployed  47<x<61
# 4981              <0  21<x<38   4793<x<9337      1<=X<4     x<19
# 4982           >=200      x<4       x>13880  unemployed  19<x<33
# 4983     no checking  38<x<55         x<250          <1     x>61
# 4984              <0  38<x<55    250<x<4793  unemployed     x<19
# 4985           >=200      x<4   4793<x<9337          <1     x<19
# 4986           >=200     x>55  9337<x<13880      1<=X<4  19<x<33
# 4987              <0  21<x<38    250<x<4793      4<=X<7     x<19
# 4988              <0      x<4    250<x<4793         >=7     x>61
# 4989        0<=X<200     x>55         x<250      4<=X<7  33<x<47
# 4990     no checking  21<x<38         x<250      1<=X<4     x<19
# 4991              <0  38<x<55         x<250  unemployed     x<19
# 4992        0<=X<200   4<x<21   4793<x<9337         >=7  47<x<61
# 4993        0<=X<200      x<4       x>13880      4<=X<7  19<x<33
# 4994        0<=X<200  38<x<55         x<250         >=7     x>61
# 4995              <0   4<x<21  9337<x<13880      4<=X<7  33<x<47
# 4996           >=200      x<4   4793<x<9337      1<=X<4     x<19
# 4997           >=200  38<x<55   4793<x<9337  unemployed  19<x<33
# 4998        0<=X<200     x>55    250<x<4793      1<=X<4     x<19
# 4999           >=200   4<x<21  9337<x<13880      1<=X<4  47<x<61
#
# [5000 rows x 22 columns]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

class DataEncoder(object):


    def __init__(self, class_column='class', cat_columns=None):
        self.class_column = class_column
        self.cat_columns = cat_columns

        # these will be trained with fit_encoders()
        self.column_encoders = {} # label encoder
        self.cat_encoder = None # one-hot encoder
        self.label_encoder = None # label encoder

    def fit(self, data):
        """
        Fit one-hot encoders for categorical features and an integer encoder for
        the label. These can be used later to transform raw data into a form
        that ATM can work with.

        data: pd.DataFrame of unprocessed data
        """
        if self.class_column not in data.columns:
            raise KeyError('Class column "%s" not found in dataset!' %
                           self.class_column)
            
        range_col = find_range_cols(data)
                
        self.range_col = range_col
            

        # encode categorical columns, leave ordinal values alone
        if self.cat_columns is None:
            cats = data.drop([self.class_column]+range_col, axis=1).select_dtypes(exclude=['int64'])
            self.cat_columns = cats.columns
        else:
            cats = data[self.cat_columns].drop(range_col, axis=1).select_dtypes(exclude=['int64'])
            
        self.cat_cols = cats.columns
        
        for cat_name in cats.columns:   
        # save the indices of categorical columns for one-hot encoding

            # encode each feature as an integer in range(unique_vals)
            le = LabelEncoder()
            cats[cat_name] = le.fit_transform(cats[cat_name])
            self.column_encoders[cat_name] = le

        # One-hot encode the whole feature matrix.
        # Set sparse to False so that we can test for NaNs in the output
        self.cat_encoder = OneHotEncoder(sparse=False)
        self.cat_encoder.fit(cats)

        # Train an encoder for the label as well
        labels = np.array(data[[self.class_column]])
        self.label_encoder = LabelEncoder()
        self.label_encoder.fit(labels)
        

    def transform(self, data):
        """
        Convert a DataFrame of labeled data to a feature matrix in the form
        that ATM can use.
        """
        y = self.transform_y(data)
        X = self.transform_x(data)

        return X, y
    
    def transform_x(self, data):
        """
        only transform x, for the generated data
        """
        cats = data[self.cat_columns]

        # encode each categorical feature as an integer
        for column, encoder in list(self.column_encoders.items()):
            cats[column] = encoder.transform(cats[column])

        # one-hot encode the categorical features
        X = self.cat_encoder.transform(cats)
        
        if self.class_column in data:
            nums = data.drop([self.class_column], axis=1).select_dtypes(include=['int64']).values
        else:
            nums = data.select_dtypes(include=['int64']).values
        # transform range cols into integrate. e.g., <4 -> 1; 4<x<7 -> 2
        ranges = []
        for col in self.range_col:
            values = data[col]
            ranges.append( self.range2int(values) )
        if(ranges==[]):
            X = np.concatenate((X, nums), axis=1)
        else:
            ranges = np.transpose( np.array(ranges) )
            X = np.concatenate((X, nums, ranges), axis=1)
        
        return X
    
    def transform_y(self, data):
        if self.class_column in data:
            # pull labels into a separate series and transform them to integers
            labels = np.array(data[[self.class_column]])
            y = self.label_encoder.transform(labels)
            # drop the label column and transform the remaining features
        else:
            y = None
            
        return y
    
    def range2int(self, values):
        ranges = []
        for v in values:
            if v not in ranges:
                ranges.append(v)
        
        def sort_key(x):
            num_strings = re.findall('\d+', x)
            # 'undefined' is in the front
            if len(num_strings)==0:
                return -1
            # x> 1, x<7
            elif len(num_strings)==1:
                return int(num_strings[0])*2
            # 1<x<7
            else:
                nums = map(int, num_strings) # string to number
                return sum(nums)
                
        ranges.sort(key=sort_key)
        return list(map(lambda x: ranges.index(x), values))
        
        
    
    def fit_transform(self, data):
        """ Process data into a form that ATM can use. """
        self.fit(data)
        return self.transform(data)
    

knn = KNeighborsClassifier(
                algorithm = "ball_tree",
                leaf_size = 40,
                metric = "manhattan",
                n_neighbors = 17
            )
    
encoder = DataEncoder()
encoder.fit(new_samples)
x_train, y_train = encoder.transform(new_samples)
knn.fit(x_train,y_train)
score = cross_val_score(knn, x_train, y_train, scoring='accuracy', cv=10) 
data
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         marriage  gender checking_status duration  \
# 0         single    male              <0   4<x<21
# 1    div/dep/mar  female        0<=X<200  38<x<55
# 2         single    male     no checking   4<x<21
# 3         single    male              <0  38<x<55
# 4         single    male              <0  21<x<38
# 5         single    male     no checking  21<x<38
# 6         single    male     no checking  21<x<38
# 7         single    male        0<=X<200  21<x<38
# 8        div/sep    male     no checking   4<x<21
# 9        mar/wid    male        0<=X<200  21<x<38
# 10   div/dep/mar  female        0<=X<200   4<x<21
# 11   div/dep/mar  female              <0  38<x<55
# 12   div/dep/mar  female        0<=X<200   4<x<21
# 13        single    male              <0  21<x<38
# 14   div/dep/mar  female              <0   4<x<21
# 15   div/dep/mar  female              <0  21<x<38
# 16        single    male     no checking  21<x<38
# 17        single    male              <0  21<x<38
# 18   div/dep/mar  female        0<=X<200  21<x<38
# 19        single    male     no checking  21<x<38
# 20        single    male     no checking   4<x<21
# 21        single    male              <0   4<x<21
# 22        single    male              <0   4<x<21
# 23        single    male        0<=X<200   4<x<21
# 24       mar/wid    male     no checking   4<x<21
# 25        single    male              <0   4<x<21
# 26       mar/wid    male     no checking   4<x<21
# 27   div/dep/mar  female           >=200   4<x<21
# 28        single    male        0<=X<200   4<x<21
# 29        single    male              <0     x>55
# ..           ...     ...             ...      ...
# 970       single    male        0<=X<200   4<x<21
# 971       single    male     no checking  21<x<38
# 972  div/dep/mar  female              <0  21<x<38
# 973       single    male              <0     x>55
# 974  div/dep/mar  female     no checking  21<x<38
# 975  div/dep/mar  female           >=200  21<x<38
# 976  div/dep/mar  female        0<=X<200   4<x<21
# 977       single    male        0<=X<200   4<x<21
# 978       single    male     no checking  21<x<38
# 979      mar/wid    male        0<=X<200   4<x<21
# 980       single    male        0<=X<200  21<x<38
# 981       single    male     no checking  38<x<55
# 982  div/dep/mar  female           >=200   4<x<21
# 983       single    male              <0  21<x<38
# 984       single    male     no checking  21<x<38
# 985  div/dep/mar  female              <0   4<x<21
# 986      div/sep    male           >=200  38<x<55
# 987  div/dep/mar  female     no checking   4<x<21
# 988       single    male              <0  21<x<38
# 989       single    male        0<=X<200  21<x<38
# 990       single    male     no checking   4<x<21
# 991       single    male     no checking   4<x<21
# 992      mar/wid    male              <0   4<x<21
# 993       single    male              <0  21<x<38
# 994       single    male     no checking   4<x<21
# 995  div/dep/mar  female     no checking   4<x<21
# 996      div/sep    male              <0  21<x<38
# 997       single    male     no checking   4<x<21
# 998       single    male              <0  38<x<55
# 999       single    male        0<=X<200  38<x<55
#
#                      credit_history              purpose credit_amount  \
# 0    critical/other existing credit             radio/tv    250<x<4793
# 1                     existing paid             radio/tv   4793<x<9337
# 2    critical/other existing credit            education    250<x<4793
# 3                     existing paid  furniture/equipment   4793<x<9337
# 4                delayed previously              new car   4793<x<9337
# 5                     existing paid            education   4793<x<9337
# 6                     existing paid  furniture/equipment    250<x<4793
# 7                     existing paid             used car   4793<x<9337
# 8                     existing paid             radio/tv    250<x<4793
# 9    critical/other existing credit              new car   4793<x<9337
# 10                    existing paid              new car    250<x<4793
# 11                    existing paid             business    250<x<4793
# 12                    existing paid             radio/tv    250<x<4793
# 13   critical/other existing credit              new car    250<x<4793
# 14                    existing paid              new car    250<x<4793
# 15                    existing paid             radio/tv    250<x<4793
# 16   critical/other existing credit             radio/tv    250<x<4793
# 17              no credits/all paid             business   4793<x<9337
# 18                    existing paid             used car  9337<x<13880
# 19                    existing paid             radio/tv    250<x<4793
# 20   critical/other existing credit              new car    250<x<4793
# 21                    existing paid             radio/tv    250<x<4793
# 22   critical/other existing credit              new car    250<x<4793
# 23   critical/other existing credit             used car    250<x<4793
# 24   critical/other existing credit  furniture/equipment    250<x<4793
# 25                    existing paid  furniture/equipment    250<x<4793
# 26              no credits/all paid             radio/tv    250<x<4793
# 27                         all paid             radio/tv    250<x<4793
# 28                    existing paid             radio/tv    250<x<4793
# 29               delayed previously             business   4793<x<9337
# ..                              ...                  ...           ...
# 970                   existing paid              repairs    250<x<4793
# 971                   existing paid              new car   4793<x<9337
# 972                        all paid              new car    250<x<4793
# 973                   existing paid             business   4793<x<9337
# 974  critical/other existing credit             radio/tv    250<x<4793
# 975                   existing paid             radio/tv    250<x<4793
# 976                   existing paid             radio/tv    250<x<4793
# 977              delayed previously             business    250<x<4793
# 978              delayed previously              new car    250<x<4793
# 979                        all paid              new car    250<x<4793
# 980  critical/other existing credit  furniture/equipment   4793<x<9337
# 981                   existing paid             business   4793<x<9337
# 982                   existing paid              new car    250<x<4793
# 983                   existing paid             used car   4793<x<9337
# 984  critical/other existing credit  furniture/equipment    250<x<4793
# 985  critical/other existing credit  furniture/equipment    250<x<4793
# 986             no credits/all paid             business   4793<x<9337
# 987                   existing paid             radio/tv    250<x<4793
# 988                   existing paid             used car   4793<x<9337
# 989  critical/other existing credit             radio/tv    250<x<4793
# 990  critical/other existing credit            education    250<x<4793
# 991                        all paid             radio/tv    250<x<4793
# 992                   existing paid             radio/tv    250<x<4793
# 993                   existing paid  furniture/equipment    250<x<4793
# 994                   existing paid              new car    250<x<4793
# 995                   existing paid  furniture/equipment    250<x<4793
# 996                   existing paid             used car    250<x<4793
# 997                   existing paid             radio/tv    250<x<4793
# 998                   existing paid             radio/tv    250<x<4793
# 999  critical/other existing credit             used car    250<x<4793
#
#        savings_status  employment  installment_commitment  ...   \
# 0    no known savings         >=7                       4  ...
# 1                <100      1<=X<4                       2  ...
# 2                <100      4<=X<7                       2  ...
# 3                <100      4<=X<7                       2  ...
# 4                <100      1<=X<4                       3  ...
# 5    no known savings      1<=X<4                       2  ...
# 6         500<=X<1000         >=7                       3  ...
# 7                <100      1<=X<4                       2  ...
# 8              >=1000      4<=X<7                       2  ...
# 9                <100  unemployed                       4  ...
# 10               <100          <1                       3  ...
# 11               <100          <1                       3  ...
# 12               <100      1<=X<4                       1  ...
# 13               <100         >=7                       4  ...
# 14               <100      1<=X<4                       2  ...
# 15         100<=X<500      1<=X<4                       4  ...
# 16   no known savings         >=7                       4  ...
# 17   no known savings          <1                       2  ...
# 18               <100         >=7                       4  ...
# 19        500<=X<1000         >=7                       3  ...
# 20               <100      1<=X<4                       4  ...
# 21        500<=X<1000      1<=X<4                       2  ...
# 22               <100          <1                       1  ...
# 23         100<=X<500          <1                       3  ...
# 24   no known savings      1<=X<4                       2  ...
# 25               <100      1<=X<4                       1  ...
# 26               <100         >=7                       4  ...
# 27             >=1000      1<=X<4                       3  ...
# 28               <100      1<=X<4                       3  ...
# 29               <100         >=7                       3  ...
# ..                ...         ...                     ...  ...
# 970        100<=X<500      1<=X<4                       4  ...
# 971              <100      1<=X<4                       1  ...
# 972              <100  unemployed                       1  ...
# 973              <100         >=7                       4  ...
# 974              <100      1<=X<4                       4  ...
# 975       500<=X<1000      1<=X<4                       3  ...
# 976              <100      1<=X<4                       2  ...
# 977  no known savings         >=7                       4  ...
# 978              <100         >=7                       4  ...
# 979        100<=X<500      1<=X<4                       2  ...
# 980              <100      4<=X<7                       2  ...
# 981              <100  unemployed                       3  ...
# 982        100<=X<500      1<=X<4                       1  ...
# 983              <100      1<=X<4                       2  ...
# 984              <100      4<=X<7                       2  ...
# 985              <100      1<=X<4                       4  ...
# 986              <100          <1                       2  ...
# 987        100<=X<500  unemployed                       2  ...
# 988              <100  unemployed                       4  ...
# 989              <100         >=7                       4  ...
# 990  no known savings          <1                       2  ...
# 991        100<=X<500         >=7                       4  ...
# 992  no known savings      4<=X<7                       2  ...
# 993              <100  unemployed                       4  ...
# 994  no known savings         >=7                       4  ...
# 995              <100      4<=X<7                       3  ...
# 996              <100      1<=X<4                       4  ...
# 997              <100         >=7                       4  ...
# 998              <100      1<=X<4                       4  ...
# 999        100<=X<500  unemployed                       3  ...
#
#     property_magnitude      age other_payment_plans   housing  \
# 0          real estate     x>61                none       own
# 1          real estate  19<x<33                none       own
# 2          real estate  47<x<61                none       own
# 3       life insurance  33<x<47                none  for free
# 4    no known property  47<x<61                none  for free
# 5    no known property  33<x<47                none  for free
# 6       life insurance  47<x<61                none       own
# 7                  car  33<x<47                none      rent
# 8          real estate  47<x<61                none       own
# 9                  car  19<x<33                none       own
# 10                 car  19<x<33                none      rent
# 11      life insurance  19<x<33                none      rent
# 12                 car  19<x<33                none       own
# 13                 car  47<x<61                none       own
# 14                 car  19<x<33                none      rent
# 15                 car  19<x<33                none       own
# 16      life insurance  47<x<61                none       own
# 17                 car  19<x<33                bank       own
# 18   no known property  33<x<47                none  for free
# 19                 car  19<x<33                none       own
# 20                 car  47<x<61                none       own
# 21         real estate  33<x<47                none      rent
# 22         real estate  47<x<61                none      rent
# 23      life insurance  33<x<47                none       own
# 24                 car  19<x<33                none       own
# 25         real estate  33<x<47                bank       own
# 26                 car  33<x<47                none       own
# 27         real estate  33<x<47                none      rent
# 28         real estate  33<x<47                none       own
# 29   no known property     x>61                none       own
# ..                 ...      ...                 ...       ...
# 970        real estate  19<x<33                none       own
# 971     life insurance  33<x<47                none       own
# 972  no known property  19<x<33                none      rent
# 973  no known property  33<x<47                none      rent
# 974                car  19<x<33                none       own
# 975                car  47<x<61                none       own
# 976        real estate     x>61                none       own
# 977     life insurance  33<x<47                none       own
# 978                car  33<x<47                none       own
# 979     life insurance  19<x<33                none      rent
# 980     life insurance  47<x<61                none       own
# 981                car  19<x<33                bank      rent
# 982                car  19<x<33                bank       own
# 983     life insurance  19<x<33                none       own
# 984     life insurance  19<x<33                none       own
# 985     life insurance  19<x<33                none      rent
# 986     life insurance  19<x<33                none       own
# 987        real estate     x>61                none       own
# 988  no known property  19<x<33                none  for free
# 989     life insurance  47<x<61                none       own
# 990     life insurance  33<x<47                none       own
# 991                car  33<x<47                bank       own
# 992                car  19<x<33                none      rent
# 993     life insurance  19<x<33                none       own
# 994                car  47<x<61                none       own
# 995        real estate  19<x<33                none       own
# 996     life insurance  33<x<47                none       own
# 997                car  33<x<47                none       own
# 998  no known property  19<x<33                none  for free
# 999                car  19<x<33                none       own
#
#     existing_credits                        job  num_dependents own_telephone  \
# 0                  2                    skilled               1           yes
# 1                  1                    skilled               1          none
# 2                  1         unskilled resident               2          none
# 3                  1                    skilled               2          none
# 4                  2                    skilled               2          none
# 5                  1         unskilled resident               2           yes
# 6                  1                    skilled               1          none
# 7                  1  high qualif/self emp/mgmt               1           yes
# 8                  1         unskilled resident               1          none
# 9                  2  high qualif/self emp/mgmt               1          none
# 10                 1                    skilled               1          none
# 11                 1                    skilled               1          none
# 12                 1                    skilled               1           yes
# 13                 2         unskilled resident               1          none
# 14                 1                    skilled               1          none
# 15                 1         unskilled resident               1          none
# 16                 2                    skilled               1          none
# 17                 3                    skilled               1          none
# 18                 1  high qualif/self emp/mgmt               1           yes
# 19                 1                    skilled               2           yes
# 20                 3                    skilled               1           yes
# 21                 1                    skilled               2          none
# 22                 2         unskilled resident               2          none
# 23                 1                    skilled               1          none
# 24                 2                    skilled               1          none
# 25                 1         unskilled resident               1           yes
# 26                 1         unskilled resident               1          none
# 27                 2                    skilled               1          none
# 28                 1                    skilled               1          none
# 29                 2                    skilled               1           yes
# ..               ...                        ...             ...           ...
# 970                1                    skilled               1          none
# 971                1         unskilled resident               2          none
# 972                2    unemp/unskilled non res               1          none
# 973                1                    skilled               1          none
# 974                1                    skilled               1           yes
# 975                1         unskilled resident               1          none
# 976                1                    skilled               1          none
# 977                2                    skilled               1          none
# 978                2         unskilled resident               2          none
# 979                1                    skilled               1          none
# 980                1                    skilled               1          none
# 981                1  high qualif/self emp/mgmt               1           yes
# 982                1  high qualif/self emp/mgmt               1           yes
# 983                1                    skilled               2          none
# 984                2         unskilled resident               1          none
# 985                2                    skilled               1          none
# 986                2                    skilled               1          none
# 987                1                    skilled               1          none
# 988                1  high qualif/self emp/mgmt               1           yes
# 989                2         unskilled resident               1          none
# 990                2         unskilled resident               2          none
# 991                1         unskilled resident               2          none
# 992                2         unskilled resident               1          none
# 993                1  high qualif/self emp/mgmt               1           yes
# 994                1                    skilled               1           yes
# 995                1         unskilled resident               1          none
# 996                1  high qualif/self emp/mgmt               1           yes
# 997                1                    skilled               1          none
# 998                1                    skilled               1           yes
# 999                1                    skilled               1          none
#
#      foreign_worker class
# 0               yes  good
# 1               yes   bad
# 2               yes  good
# 3               yes  good
# 4               yes   bad
# 5               yes  good
# 6               yes  good
# 7               yes  good
# 8               yes  good
# 9               yes   bad
# 10              yes   bad
# 11              yes   bad
# 12              yes  good
# 13              yes   bad
# 14              yes  good
# 15              yes   bad
# 16              yes  good
# 17              yes  good
# 18              yes   bad
# 19              yes  good
# 20              yes  good
# 21              yes  good
# 22               no  good
# 23              yes  good
# 24               no  good
# 25              yes  good
# 26              yes  good
# 27              yes  good
# 28              yes  good
# 29              yes   bad
# ..              ...   ...
# 970             yes  good
# 971             yes  good
# 972             yes   bad
# 973             yes   bad
# 974             yes  good
# 975             yes  good
# 976             yes  good
# 977             yes  good
# 978             yes   bad
# 979             yes   bad
# 980             yes   bad
# 981             yes   bad
# 982             yes  good
# 983             yes   bad
# 984             yes  good
# 985             yes  good
# 986             yes  good
# 987             yes  good
# 988             yes  good
# 989             yes  good
# 990             yes  good
# 991             yes  good
# 992             yes  good
# 993             yes  good
# 994             yes  good
# 995             yes  good
# 996             yes  good
# 997             yes  good
# 998             yes   bad
# 999             yes  good
#
# [1000 rows x 22 columns]

# %%
def generate_model_samples(data, sample_num, model, encoder):
    """
    models behavior on generated sample data:
    Args:
        data(pandas DataFrame): training data
        sample_num(int): 
        model(sklearn model object): already trained model
        encoder(instance of DataGene): instance of DataGene, already fit 
    Return:
        model_samples(pandas DataFrame): generated samples + model prected labels
    """
    dataGene = DataGene(data, sample_num)
    new_samples = dataGene.get_samples()
    samplesInit = new_samples
    print(samplesInit)
    samples = num2cate(samplesInit)
    print(samplesInit)
    # model predict
    #print(samples)
    x_samples, _ = encoder.transform(samples)
    #print(x_samples.size)
    y_samples = knn.predict(x_samples)
    
    #  concate 
    model_samples = samples.copy()
    model_samples['class'] = pd.Series(np.asarray(y_samples), index= samples.index) 

    return model_samples, samplesInit

x,y = generate_model_samples(data,sample_number ,knn, encoder)
y
# Out:
# Index(['installment_commitment', 'residence_since', 'existing_credits',
#        'num_dependents'],
#       dtype='object')
#          marriage  gender                  credit_history  \
# 0         div/sep  female                        all paid
# 1         div/sep  female              delayed previously
# 2         div/sep    male             no credits/all paid
# 3     div/dep/mar    male              delayed previously
# 4          single    male                        all paid
# 5          single  female  critical/other existing credit
# 6          single    male                        all paid
# 7         div/sep    male                   existing paid
# 8         mar/wid    male                   existing paid
# 9          single  female  critical/other existing credit
# 10         single    male                   existing paid
# 11    div/dep/mar    male                   existing paid
# 12    div/dep/mar  female                   existing paid
# 13        div/sep  female              delayed previously
# 14        div/sep    male              delayed previously
# 15         single  female                   existing paid
# 16         single  female  critical/other existing credit
# 17        mar/wid    male              delayed previously
# 18         single  female                   existing paid
# 19        mar/wid    male              delayed previously
# 20    div/dep/mar    male                   existing paid
# 21        mar/wid    male                        all paid
# 22        div/sep    male  critical/other existing credit
# 23        mar/wid    male  critical/other existing credit
# 24        mar/wid  female             no credits/all paid
# 25        mar/wid  female             no credits/all paid
# 26    div/dep/mar  female  critical/other existing credit
# 27        mar/wid  female             no credits/all paid
# 28        div/sep    male                        all paid
# 29        mar/wid  female                        all paid
# ...           ...     ...                             ...
# 4970  div/dep/mar    male  critical/other existing credit
# 4971      mar/wid  female                   existing paid
# 4972       single  female                        all paid
# 4973      div/sep    male                        all paid
# 4974  div/dep/mar    male  critical/other existing credit
# 4975      mar/wid    male             no credits/all paid
# 4976  div/dep/mar  female  critical/other existing credit
# 4977  div/dep/mar  female                   existing paid
# 4978      div/sep    male                        all paid
# 4979      div/sep    male             no credits/all paid
# 4980  div/dep/mar    male                        all paid
# 4981      div/sep  female                        all paid
# 4982      mar/wid  female                   existing paid
# 4983       single  female  critical/other existing credit
# 4984      div/sep  female                   existing paid
# 4985  div/dep/mar  female  critical/other existing credit
# 4986       single  female                   existing paid
# 4987      mar/wid  female                   existing paid
# 4988      div/sep  female             no credits/all paid
# 4989      div/sep  female                   existing paid
# 4990       single    male              delayed previously
# 4991       single  female                        all paid
# 4992      mar/wid  female  critical/other existing credit
# 4993      div/sep    male  critical/other existing credit
# 4994  div/dep/mar  female                        all paid
# 4995       single  female  critical/other existing credit
# 4996      mar/wid    male              delayed previously
# 4997       single  female             no credits/all paid
# 4998      div/sep    male  critical/other existing credit
# 4999      div/sep    male              delayed previously
#
#                   purpose    savings_status other_parties property_magnitude  \
# 0                 repairs            >=1000     guarantor                car
# 1                radio/tv        100<=X<500     guarantor  no known property
# 2      domestic appliance       500<=X<1000     guarantor  no known property
# 3                used car        100<=X<500          none     life insurance
# 4     furniture/equipment       500<=X<1000          none                car
# 5              retraining  no known savings     guarantor     life insurance
# 6     furniture/equipment            >=1000  co applicant        real estate
# 7                radio/tv        100<=X<500     guarantor  no known property
# 8                used car  no known savings          none     life insurance
# 9                 repairs              <100  co applicant        real estate
# 10     domestic appliance  no known savings     guarantor                car
# 11                new car       500<=X<1000          none  no known property
# 12               business        100<=X<500     guarantor        real estate
# 13     domestic appliance        100<=X<500     guarantor        real estate
# 14     domestic appliance  no known savings  co applicant        real estate
# 15    furniture/equipment       500<=X<1000          none                car
# 16    furniture/equipment        100<=X<500          none        real estate
# 17              education  no known savings  co applicant        real estate
# 18    furniture/equipment            >=1000          none  no known property
# 19                  other              <100  co applicant     life insurance
# 20                repairs  no known savings     guarantor                car
# 21               used car            >=1000          none        real estate
# 22               business        100<=X<500     guarantor        real estate
# 23                repairs        100<=X<500     guarantor     life insurance
# 24              education       500<=X<1000  co applicant        real estate
# 25     domestic appliance              <100     guarantor  no known property
# 26                new car       500<=X<1000     guarantor        real estate
# 27                repairs       500<=X<1000  co applicant     life insurance
# 28              education       500<=X<1000          none     life insurance
# 29               business            >=1000     guarantor     life insurance
# ...                   ...               ...           ...                ...
# 4970                other        100<=X<500  co applicant  no known property
# 4971            education  no known savings     guarantor        real estate
# 4972            education              <100          none  no known property
# 4973             radio/tv              <100          none  no known property
# 4974   domestic appliance              <100          none                car
# 4975   domestic appliance        100<=X<500          none                car
# 4976              new car       500<=X<1000  co applicant  no known property
# 4977  furniture/equipment              <100          none                car
# 4978              repairs              <100  co applicant  no known property
# 4979   domestic appliance       500<=X<1000          none                car
# 4980                other  no known savings          none  no known property
# 4981             business            >=1000     guarantor     life insurance
# 4982              repairs       500<=X<1000  co applicant        real estate
# 4983            education        100<=X<500     guarantor     life insurance
# 4984              repairs  no known savings  co applicant     life insurance
# 4985  furniture/equipment        100<=X<500     guarantor                car
# 4986             radio/tv              <100     guarantor  no known property
# 4987             radio/tv        100<=X<500  co applicant     life insurance
# 4988           retraining  no known savings  co applicant  no known property
# 4989                other              <100          none                car
# 4990             radio/tv            >=1000  co applicant  no known property
# 4991              new car            >=1000          none                car
# 4992             used car            >=1000     guarantor  no known property
# 4993             radio/tv       500<=X<1000          none        real estate
# 4994              new car       500<=X<1000     guarantor                car
# 4995             radio/tv        100<=X<500  co applicant        real estate
# 4996                other  no known savings  co applicant  no known property
# 4997             business       500<=X<1000     guarantor  no known property
# 4998  furniture/equipment            >=1000  co applicant     life insurance
# 4999           retraining        100<=X<500  co applicant  no known property
#
#      other_payment_plans   housing                        job   ...    class  \
# 0                   none       own    unemp/unskilled non res   ...      bad
# 1                   none  for free    unemp/unskilled non res   ...      bad
# 2                   none  for free    unemp/unskilled non res   ...     good
# 3                 stores      rent         unskilled resident   ...     good
# 4                   none       own         unskilled resident   ...     good
# 5                   bank      rent    unemp/unskilled non res   ...     good
# 6                 stores      rent         unskilled resident   ...      bad
# 7                   none      rent         unskilled resident   ...     good
# 8                   none      rent                    skilled   ...      bad
# 9                 stores       own                    skilled   ...      bad
# 10                  none      rent         unskilled resident   ...      bad
# 11                  none      rent    unemp/unskilled non res   ...     good
# 12                  bank      rent  high qualif/self emp/mgmt   ...     good
# 13                stores       own         unskilled resident   ...     good
# 14                  bank      rent    unemp/unskilled non res   ...     good
# 15                stores      rent         unskilled resident   ...     good
# 16                stores      rent    unemp/unskilled non res   ...      bad
# 17                  bank       own    unemp/unskilled non res   ...      bad
# 18                  none      rent  high qualif/self emp/mgmt   ...     good
# 19                  bank  for free                    skilled   ...      bad
# 20                stores       own  high qualif/self emp/mgmt   ...      bad
# 21                  none  for free    unemp/unskilled non res   ...     good
# 22                  bank  for free         unskilled resident   ...     good
# 23                  bank       own         unskilled resident   ...      bad
# 24                stores       own         unskilled resident   ...      bad
# 25                  none       own  high qualif/self emp/mgmt   ...     good
# 26                  bank       own  high qualif/self emp/mgmt   ...     good
# 27                stores       own         unskilled resident   ...     good
# 28                  none      rent                    skilled   ...      bad
# 29                  none  for free  high qualif/self emp/mgmt   ...     good
# ...                  ...       ...                        ...   ...      ...
# 4970                none      rent    unemp/unskilled non res   ...      bad
# 4971                none       own    unemp/unskilled non res   ...      bad
# 4972                bank      rent                    skilled   ...     good
# 4973                bank  for free    unemp/unskilled non res   ...     good
# 4974                none       own    unemp/unskilled non res   ...      bad
# 4975                none  for free                    skilled   ...      bad
# 4976                bank  for free  high qualif/self emp/mgmt   ...     good
# 4977                none       own         unskilled resident   ...     good
# 4978                bank      rent         unskilled resident   ...      bad
# 4979                bank       own    unemp/unskilled non res   ...      bad
# 4980                bank       own  high qualif/self emp/mgmt   ...      bad
# 4981              stores       own                    skilled   ...     good
# 4982              stores  for free         unskilled resident   ...      bad
# 4983                none  for free                    skilled   ...     good
# 4984                bank       own                    skilled   ...     good
# 4985                bank      rent    unemp/unskilled non res   ...     good
# 4986                none       own  high qualif/self emp/mgmt   ...     good
# 4987                none       own         unskilled resident   ...     good
# 4988                bank  for free  high qualif/self emp/mgmt   ...     good
# 4989                none       own                    skilled   ...     good
# 4990              stores  for free                    skilled   ...      bad
# 4991                none       own  high qualif/self emp/mgmt   ...      bad
# 4992                bank      rent    unemp/unskilled non res   ...      bad
# 4993              stores      rent    unemp/unskilled non res   ...      bad
# 4994                none      rent  high qualif/self emp/mgmt   ...      bad
# 4995              stores       own  high qualif/self emp/mgmt   ...      bad
# 4996              stores      rent    unemp/unskilled non res   ...     good
# 4997              stores      rent  high qualif/self emp/mgmt   ...      bad
# 4998                bank       own                    skilled   ...      bad
# 4999                none  for free         unskilled resident   ...      bad
#
#      installment_commitment residence_since  existing_credits  num_dependents  \
# 0                         4               2                 3               2
# 1                         2               2                 1               2
# 2                         1               1                 4               1
# 3                         3               1                 2               1
# 4                         2               1                 2               1
# 5                         1               3                 4               2
# 6                         1               3                 2               2
# 7                         3               3                 1               2
# 8                         1               4                 1               1
# 9                         4               1                 2               1
# 10                        4               3                 4               2
# 11                        1               4                 1               2
# 12                        4               1                 4               2
# 13                        4               3                 2               1
# 14                        4               1                 2               1
# 15                        2               1                 4               2
# 16                        2               4                 3               2
# 17                        1               4                 1               2
# 18                        2               1                 2               1
# 19                        3               1                 4               1
# 20                        3               4                 4               1
# 21                        3               3                 1               1
# 22                        4               4                 4               2
# 23                        4               1                 2               1
# 24                        4               2                 2               2
# 25                        2               3                 1               2
# 26                        1               3                 3               1
# 27                        1               2                 1               2
# 28                        2               3                 1               2
# 29                        3               1                 2               2
# ...                     ...             ...               ...             ...
# 4970                      1               1                 1               2
# 4971                      3               4                 1               2
# 4972                      3               4                 1               2
# 4973                      1               4                 3               2
# 4974                      3               3                 2               1
# 4975                      2               3                 1               1
# 4976                      3               2                 4               2
# 4977                      1               4                 1               1
# 4978                      4               2                 3               2
# 4979                      2               3                 3               2
# 4980                      4               1                 2               2
# 4981                      4               3                 1               2
# 4982                      3               1                 3               1
# 4983                      2               4                 3               1
# 4984                      4               2                 3               1
# 4985                      1               2                 1               1
# 4986                      2               4                 4               1
# 4987                      1               1                 1               2
# 4988                      1               4                 4               2
# 4989                      1               2                 1               1
# 4990                      2               2                 1               2
# 4991                      4               1                 1               2
# 4992                      4               1                 3               2
# 4993                      1               2                 4               2
# 4994                      1               2                 2               1
# 4995                      3               3                 3               1
# 4996                      1               2                 1               1
# 4997                      1               2                 4               1
# 4998                      3               1                 2               2
# 4999                      3               1                 2               2
#
#       checking_status  duration credit_amount  employment      age
# 0         no checking       x<4         x<250      1<=X<4     x<19
# 1                  <0   38<x<55       x>13880         >=7  19<x<33
# 2                  <0   38<x<55  9337<x<13880      4<=X<7  33<x<47
# 3                  <0      x>55    250<x<4793          <1  33<x<47
# 4            0<=X<200       x<4   4793<x<9337      4<=X<7     x>61
# 5                  <0   21<x<38    250<x<4793          <1  33<x<47
# 6                  <0    4<x<21         x<250      1<=X<4  33<x<47
# 7         no checking    4<x<21       x>13880  unemployed  33<x<47
# 8                  <0       x<4  9337<x<13880          <1  19<x<33
# 9            0<=X<200   38<x<55       x>13880      4<=X<7     x<19
# 10           0<=X<200   21<x<38    250<x<4793      4<=X<7  47<x<61
# 11        no checking   38<x<55         x<250      4<=X<7     x<19
# 12              >=200   21<x<38         x<250          <1  33<x<47
# 13                 <0    4<x<21  9337<x<13880  unemployed  19<x<33
# 14           0<=X<200      x>55    250<x<4793      4<=X<7  33<x<47
# 15              >=200   21<x<38   4793<x<9337      1<=X<4     x>61
# 16                 <0       x<4       x>13880         >=7     x>61
# 17        no checking    4<x<21         x<250         >=7     x<19
# 18           0<=X<200   21<x<38   4793<x<9337          <1  47<x<61
# 19              >=200       x<4  9337<x<13880      1<=X<4  33<x<47
# 20        no checking      x>55       x>13880          <1  19<x<33
# 21              >=200    4<x<21    250<x<4793      4<=X<7  47<x<61
# 22           0<=X<200      x>55   4793<x<9337  unemployed     x>61
# 23        no checking    4<x<21       x>13880      1<=X<4     x<19
# 24           0<=X<200   38<x<55   4793<x<9337  unemployed     x<19
# 25           0<=X<200   38<x<55    250<x<4793      1<=X<4  33<x<47
# 26        no checking      x>55  9337<x<13880      4<=X<7  47<x<61
# 27                 <0      x>55    250<x<4793          <1  33<x<47
# 28           0<=X<200      x>55  9337<x<13880      4<=X<7     x<19
# 29        no checking       x<4   4793<x<9337  unemployed     x>61
# ...               ...       ...           ...         ...      ...
# 4970         0<=X<200      x>55    250<x<4793      1<=X<4     x<19
# 4971            >=200   21<x<38  9337<x<13880  unemployed  19<x<33
# 4972               <0   21<x<38  9337<x<13880      1<=X<4  33<x<47
# 4973      no checking    4<x<21    250<x<4793      4<=X<7  19<x<33
# 4974         0<=X<200       x<4         x<250      4<=X<7  47<x<61
# 4975            >=200   38<x<55  9337<x<13880          <1  19<x<33
# 4976            >=200   21<x<38  9337<x<13880          <1  47<x<61
# 4977            >=200    4<x<21       x>13880      4<=X<7     x<19
# 4978         0<=X<200    4<x<21  9337<x<13880          <1  47<x<61
# 4979            >=200    4<x<21   4793<x<9337      4<=X<7     x<19
# 4980      no checking      x>55    250<x<4793          <1  33<x<47
# 4981               <0       x<4   4793<x<9337         >=7     x<19
# 4982         0<=X<200      x>55  9337<x<13880  unemployed  33<x<47
# 4983            >=200      x>55       x>13880  unemployed     x<19
# 4984               <0   38<x<55   4793<x<9337          <1     x<19
# 4985               <0      x>55       x>13880      4<=X<7  19<x<33
# 4986               <0   21<x<38         x<250          <1     x>61
# 4987            >=200       x<4   4793<x<9337      1<=X<4     x<19
# 4988      no checking       x<4   4793<x<9337      1<=X<4  19<x<33
# 4989      no checking      x>55         x<250  unemployed  33<x<47
# 4990         0<=X<200    4<x<21    250<x<4793          <1  19<x<33
# 4991               <0   21<x<38         x<250          <1     x>61
# 4992         0<=X<200      x>55    250<x<4793          <1     x>61
# 4993         0<=X<200      x>55   4793<x<9337         >=7     x>61
# 4994               <0   21<x<38         x<250      1<=X<4  19<x<33
# 4995               <0   38<x<55   4793<x<9337      4<=X<7     x>61
# 4996               <0      x>55         x<250      4<=X<7  33<x<47
# 4997            >=200    4<x<21       x>13880         >=7  19<x<33
# 4998      no checking   21<x<38  9337<x<13880         >=7  19<x<33
# 4999      no checking   21<x<38       x>13880          <1     x>61
#
# [5000 rows x 22 columns]
#          marriage  gender                  credit_history  \
# 0         div/sep  female                        all paid
# 1         div/sep  female              delayed previously
# 2         div/sep    male             no credits/all paid
# 3     div/dep/mar    male              delayed previously
# 4          single    male                        all paid
# 5          single  female  critical/other existing credit
# 6          single    male                        all paid
# 7         div/sep    male                   existing paid
# 8         mar/wid    male                   existing paid
# 9          single  female  critical/other existing credit
# 10         single    male                   existing paid
# 11    div/dep/mar    male                   existing paid
# 12    div/dep/mar  female                   existing paid
# 13        div/sep  female              delayed previously
# 14        div/sep    male              delayed previously
# 15         single  female                   existing paid
# 16         single  female  critical/other existing credit
# 17        mar/wid    male              delayed previously
# 18         single  female                   existing paid
# 19        mar/wid    male              delayed previously
# 20    div/dep/mar    male                   existing paid
# 21        mar/wid    male                        all paid
# 22        div/sep    male  critical/other existing credit
# 23        mar/wid    male  critical/other existing credit
# 24        mar/wid  female             no credits/all paid
# 25        mar/wid  female             no credits/all paid
# 26    div/dep/mar  female  critical/other existing credit
# 27        mar/wid  female             no credits/all paid
# 28        div/sep    male                        all paid
# 29        mar/wid  female                        all paid
# ...           ...     ...                             ...
# 4970  div/dep/mar    male  critical/other existing credit
# 4971      mar/wid  female                   existing paid
# 4972       single  female                        all paid
# 4973      div/sep    male                        all paid
# 4974  div/dep/mar    male  critical/other existing credit
# 4975      mar/wid    male             no credits/all paid
# 4976  div/dep/mar  female  critical/other existing credit
# 4977  div/dep/mar  female                   existing paid
# 4978      div/sep    male                        all paid
# 4979      div/sep    male             no credits/all paid
# 4980  div/dep/mar    male                        all paid
# 4981      div/sep  female                        all paid
# 4982      mar/wid  female                   existing paid
# 4983       single  female  critical/other existing credit
# 4984      div/sep  female                   existing paid
# 4985  div/dep/mar  female  critical/other existing credit
# 4986       single  female                   existing paid
# 4987      mar/wid  female                   existing paid
# 4988      div/sep  female             no credits/all paid
# 4989      div/sep  female                   existing paid
# 4990       single    male              delayed previously
# 4991       single  female                        all paid
# 4992      mar/wid  female  critical/other existing credit
# 4993      div/sep    male  critical/other existing credit
# 4994  div/dep/mar  female                        all paid
# 4995       single  female  critical/other existing credit
# 4996      mar/wid    male              delayed previously
# 4997       single  female             no credits/all paid
# 4998      div/sep    male  critical/other existing credit
# 4999      div/sep    male              delayed previously
#
#                   purpose    savings_status other_parties property_magnitude  \
# 0                 repairs            >=1000     guarantor                car
# 1                radio/tv        100<=X<500     guarantor  no known property
# 2      domestic appliance       500<=X<1000     guarantor  no known property
# 3                used car        100<=X<500          none     life insurance
# 4     furniture/equipment       500<=X<1000          none                car
# 5              retraining  no known savings     guarantor     life insurance
# 6     furniture/equipment            >=1000  co applicant        real estate
# 7                radio/tv        100<=X<500     guarantor  no known property
# 8                used car  no known savings          none     life insurance
# 9                 repairs              <100  co applicant        real estate
# 10     domestic appliance  no known savings     guarantor                car
# 11                new car       500<=X<1000          none  no known property
# 12               business        100<=X<500     guarantor        real estate
# 13     domestic appliance        100<=X<500     guarantor        real estate
# 14     domestic appliance  no known savings  co applicant        real estate
# 15    furniture/equipment       500<=X<1000          none                car
# 16    furniture/equipment        100<=X<500          none        real estate
# 17              education  no known savings  co applicant        real estate
# 18    furniture/equipment            >=1000          none  no known property
# 19                  other              <100  co applicant     life insurance
# 20                repairs  no known savings     guarantor                car
# 21               used car            >=1000          none        real estate
# 22               business        100<=X<500     guarantor        real estate
# 23                repairs        100<=X<500     guarantor     life insurance
# 24              education       500<=X<1000  co applicant        real estate
# 25     domestic appliance              <100     guarantor  no known property
# 26                new car       500<=X<1000     guarantor        real estate
# 27                repairs       500<=X<1000  co applicant     life insurance
# 28              education       500<=X<1000          none     life insurance
# 29               business            >=1000     guarantor     life insurance
# ...                   ...               ...           ...                ...
# 4970                other        100<=X<500  co applicant  no known property
# 4971            education  no known savings     guarantor        real estate
# 4972            education              <100          none  no known property
# 4973             radio/tv              <100          none  no known property
# 4974   domestic appliance              <100          none                car
# 4975   domestic appliance        100<=X<500          none                car
# 4976              new car       500<=X<1000  co applicant  no known property
# 4977  furniture/equipment              <100          none                car
# 4978              repairs              <100  co applicant  no known property
# 4979   domestic appliance       500<=X<1000          none                car
# 4980                other  no known savings          none  no known property
# 4981             business            >=1000     guarantor     life insurance
# 4982              repairs       500<=X<1000  co applicant        real estate
# 4983            education        100<=X<500     guarantor     life insurance
# 4984              repairs  no known savings  co applicant     life insurance
# 4985  furniture/equipment        100<=X<500     guarantor                car
# 4986             radio/tv              <100     guarantor  no known property
# 4987             radio/tv        100<=X<500  co applicant     life insurance
# 4988           retraining  no known savings  co applicant  no known property
# 4989                other              <100          none                car
# 4990             radio/tv            >=1000  co applicant  no known property
# 4991              new car            >=1000          none                car
# 4992             used car            >=1000     guarantor  no known property
# 4993             radio/tv       500<=X<1000          none        real estate
# 4994              new car       500<=X<1000     guarantor                car
# 4995             radio/tv        100<=X<500  co applicant        real estate
# 4996                other  no known savings  co applicant  no known property
# 4997             business       500<=X<1000     guarantor  no known property
# 4998  furniture/equipment            >=1000  co applicant     life insurance
# 4999           retraining        100<=X<500  co applicant  no known property
#
#      other_payment_plans   housing                        job   ...    class  \
# 0                   none       own    unemp/unskilled non res   ...      bad
# 1                   none  for free    unemp/unskilled non res   ...      bad
# 2                   none  for free    unemp/unskilled non res   ...     good
# 3                 stores      rent         unskilled resident   ...     good
# 4                   none       own         unskilled resident   ...     good
# 5                   bank      rent    unemp/unskilled non res   ...     good
# 6                 stores      rent         unskilled resident   ...      bad
# 7                   none      rent         unskilled resident   ...     good
# 8                   none      rent                    skilled   ...      bad
# 9                 stores       own                    skilled   ...      bad
# 10                  none      rent         unskilled resident   ...      bad
# 11                  none      rent    unemp/unskilled non res   ...     good
# 12                  bank      rent  high qualif/self emp/mgmt   ...     good
# 13                stores       own         unskilled resident   ...     good
# 14                  bank      rent    unemp/unskilled non res   ...     good
# 15                stores      rent         unskilled resident   ...     good
# 16                stores      rent    unemp/unskilled non res   ...      bad
# 17                  bank       own    unemp/unskilled non res   ...      bad
# 18                  none      rent  high qualif/self emp/mgmt   ...     good
# 19                  bank  for free                    skilled   ...      bad
# 20                stores       own  high qualif/self emp/mgmt   ...      bad
# 21                  none  for free    unemp/unskilled non res   ...     good
# 22                  bank  for free         unskilled resident   ...     good
# 23                  bank       own         unskilled resident   ...      bad
# 24                stores       own         unskilled resident   ...      bad
# 25                  none       own  high qualif/self emp/mgmt   ...     good
# 26                  bank       own  high qualif/self emp/mgmt   ...     good
# 27                stores       own         unskilled resident   ...     good
# 28                  none      rent                    skilled   ...      bad
# 29                  none  for free  high qualif/self emp/mgmt   ...     good
# ...                  ...       ...                        ...   ...      ...
# 4970                none      rent    unemp/unskilled non res   ...      bad
# 4971                none       own    unemp/unskilled non res   ...      bad
# 4972                bank      rent                    skilled   ...     good
# 4973                bank  for free    unemp/unskilled non res   ...     good
# 4974                none       own    unemp/unskilled non res   ...      bad
# 4975                none  for free                    skilled   ...      bad
# 4976                bank  for free  high qualif/self emp/mgmt   ...     good
# 4977                none       own         unskilled resident   ...     good
# 4978                bank      rent         unskilled resident   ...      bad
# 4979                bank       own    unemp/unskilled non res   ...      bad
# 4980                bank       own  high qualif/self emp/mgmt   ...      bad
# 4981              stores       own                    skilled   ...     good
# 4982              stores  for free         unskilled resident   ...      bad
# 4983                none  for free                    skilled   ...     good
# 4984                bank       own                    skilled   ...     good
# 4985                bank      rent    unemp/unskilled non res   ...     good
# 4986                none       own  high qualif/self emp/mgmt   ...     good
# 4987                none       own         unskilled resident   ...     good
# 4988                bank  for free  high qualif/self emp/mgmt   ...     good
# 4989                none       own                    skilled   ...     good
# 4990              stores  for free                    skilled   ...      bad
# 4991                none       own  high qualif/self emp/mgmt   ...      bad
# 4992                bank      rent    unemp/unskilled non res   ...      bad
# 4993              stores      rent    unemp/unskilled non res   ...      bad
# 4994                none      rent  high qualif/self emp/mgmt   ...      bad
# 4995              stores       own  high qualif/self emp/mgmt   ...      bad
# 4996              stores      rent    unemp/unskilled non res   ...     good
# 4997              stores      rent  high qualif/self emp/mgmt   ...      bad
# 4998                bank       own                    skilled   ...      bad
# 4999                none  for free         unskilled resident   ...      bad
#
#      installment_commitment residence_since  existing_credits  num_dependents  \
# 0                         4               2                 3               2
# 1                         2               2                 1               2
# 2                         1               1                 4               1
# 3                         3               1                 2               1
# 4                         2               1                 2               1
# 5                         1               3                 4               2
# 6                         1               3                 2               2
# 7                         3               3                 1               2
# 8                         1               4                 1               1
# 9                         4               1                 2               1
# 10                        4               3                 4               2
# 11                        1               4                 1               2
# 12                        4               1                 4               2
# 13                        4               3                 2               1
# 14                        4               1                 2               1
# 15                        2               1                 4               2
# 16                        2               4                 3               2
# 17                        1               4                 1               2
# 18                        2               1                 2               1
# 19                        3               1                 4               1
# 20                        3               4                 4               1
# 21                        3               3                 1               1
# 22                        4               4                 4               2
# 23                        4               1                 2               1
# 24                        4               2                 2               2
# 25                        2               3                 1               2
# 26                        1               3                 3               1
# 27                        1               2                 1               2
# 28                        2               3                 1               2
# 29                        3               1                 2               2
# ...                     ...             ...               ...             ...
# 4970                      1               1                 1               2
# 4971                      3               4                 1               2
# 4972                      3               4                 1               2
# 4973                      1               4                 3               2
# 4974                      3               3                 2               1
# 4975                      2               3                 1               1
# 4976                      3               2                 4               2
# 4977                      1               4                 1               1
# 4978                      4               2                 3               2
# 4979                      2               3                 3               2
# 4980                      4               1                 2               2
# 4981                      4               3                 1               2
# 4982                      3               1                 3               1
# 4983                      2               4                 3               1
# 4984                      4               2                 3               1
# 4985                      1               2                 1               1
# 4986                      2               4                 4               1
# 4987                      1               1                 1               2
# 4988                      1               4                 4               2
# 4989                      1               2                 1               1
# 4990                      2               2                 1               2
# 4991                      4               1                 1               2
# 4992                      4               1                 3               2
# 4993                      1               2                 4               2
# 4994                      1               2                 2               1
# 4995                      3               3                 3               1
# 4996                      1               2                 1               1
# 4997                      1               2                 4               1
# 4998                      3               1                 2               2
# 4999                      3               1                 2               2
#
#       checking_status  duration credit_amount  employment      age
# 0         no checking       x<4         x<250      1<=X<4     x<19
# 1                  <0   38<x<55       x>13880         >=7  19<x<33
# 2                  <0   38<x<55  9337<x<13880      4<=X<7  33<x<47
# 3                  <0      x>55    250<x<4793          <1  33<x<47
# 4            0<=X<200       x<4   4793<x<9337      4<=X<7     x>61
# 5                  <0   21<x<38    250<x<4793          <1  33<x<47
# 6                  <0    4<x<21         x<250      1<=X<4  33<x<47
# 7         no checking    4<x<21       x>13880  unemployed  33<x<47
# 8                  <0       x<4  9337<x<13880          <1  19<x<33
# 9            0<=X<200   38<x<55       x>13880      4<=X<7     x<19
# 10           0<=X<200   21<x<38    250<x<4793      4<=X<7  47<x<61
# 11        no checking   38<x<55         x<250      4<=X<7     x<19
# 12              >=200   21<x<38         x<250          <1  33<x<47
# 13                 <0    4<x<21  9337<x<13880  unemployed  19<x<33
# 14           0<=X<200      x>55    250<x<4793      4<=X<7  33<x<47
# 15              >=200   21<x<38   4793<x<9337      1<=X<4     x>61
# 16                 <0       x<4       x>13880         >=7     x>61
# 17        no checking    4<x<21         x<250         >=7     x<19
# 18           0<=X<200   21<x<38   4793<x<9337          <1  47<x<61
# 19              >=200       x<4  9337<x<13880      1<=X<4  33<x<47
# 20        no checking      x>55       x>13880          <1  19<x<33
# 21              >=200    4<x<21    250<x<4793      4<=X<7  47<x<61
# 22           0<=X<200      x>55   4793<x<9337  unemployed     x>61
# 23        no checking    4<x<21       x>13880      1<=X<4     x<19
# 24           0<=X<200   38<x<55   4793<x<9337  unemployed     x<19
# 25           0<=X<200   38<x<55    250<x<4793      1<=X<4  33<x<47
# 26        no checking      x>55  9337<x<13880      4<=X<7  47<x<61
# 27                 <0      x>55    250<x<4793          <1  33<x<47
# 28           0<=X<200      x>55  9337<x<13880      4<=X<7     x<19
# 29        no checking       x<4   4793<x<9337  unemployed     x>61
# ...               ...       ...           ...         ...      ...
# 4970         0<=X<200      x>55    250<x<4793      1<=X<4     x<19
# 4971            >=200   21<x<38  9337<x<13880  unemployed  19<x<33
# 4972               <0   21<x<38  9337<x<13880      1<=X<4  33<x<47
# 4973      no checking    4<x<21    250<x<4793      4<=X<7  19<x<33
# 4974         0<=X<200       x<4         x<250      4<=X<7  47<x<61
# 4975            >=200   38<x<55  9337<x<13880          <1  19<x<33
# 4976            >=200   21<x<38  9337<x<13880          <1  47<x<61
# 4977            >=200    4<x<21       x>13880      4<=X<7     x<19
# 4978         0<=X<200    4<x<21  9337<x<13880          <1  47<x<61
# 4979            >=200    4<x<21   4793<x<9337      4<=X<7     x<19
# 4980      no checking      x>55    250<x<4793          <1  33<x<47
# 4981               <0       x<4   4793<x<9337         >=7     x<19
# 4982         0<=X<200      x>55  9337<x<13880  unemployed  33<x<47
# 4983            >=200      x>55       x>13880  unemployed     x<19
# 4984               <0   38<x<55   4793<x<9337          <1     x<19
# 4985               <0      x>55       x>13880      4<=X<7  19<x<33
# 4986               <0   21<x<38         x<250          <1     x>61
# 4987            >=200       x<4   4793<x<9337      1<=X<4     x<19
# 4988      no checking       x<4   4793<x<9337      1<=X<4  19<x<33
# 4989      no checking      x>55         x<250  unemployed  33<x<47
# 4990         0<=X<200    4<x<21    250<x<4793          <1  19<x<33
# 4991               <0   21<x<38         x<250          <1     x>61
# 4992         0<=X<200      x>55    250<x<4793          <1     x>61
# 4993         0<=X<200      x>55   4793<x<9337         >=7     x>61
# 4994               <0   21<x<38         x<250      1<=X<4  19<x<33
# 4995               <0   38<x<55   4793<x<9337      4<=X<7     x>61
# 4996               <0      x>55         x<250      4<=X<7  33<x<47
# 4997            >=200    4<x<21       x>13880         >=7  19<x<33
# 4998      no checking   21<x<38  9337<x<13880         >=7  19<x<33
# 4999      no checking   21<x<38       x>13880          <1     x>61
#
# [5000 rows x 22 columns]
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          marriage  gender                  credit_history  \
# 0         div/sep  female                        all paid
# 1         div/sep  female              delayed previously
# 2         div/sep    male             no credits/all paid
# 3     div/dep/mar    male              delayed previously
# 4          single    male                        all paid
# 5          single  female  critical/other existing credit
# 6          single    male                        all paid
# 7         div/sep    male                   existing paid
# 8         mar/wid    male                   existing paid
# 9          single  female  critical/other existing credit
# 10         single    male                   existing paid
# 11    div/dep/mar    male                   existing paid
# 12    div/dep/mar  female                   existing paid
# 13        div/sep  female              delayed previously
# 14        div/sep    male              delayed previously
# 15         single  female                   existing paid
# 16         single  female  critical/other existing credit
# ...
# 4979   domestic appliance       500<=X<1000          none                car
# 4980                other  no known savings          none  no known property
# 4981             business            >=1000     guarantor     life insurance
# 4982              repairs       500<=X<1000  co applicant        real estate
# 4983            education        100<=X<500     guarantor     life insurance
# 4984              repairs  no known savings  co applicant     life insurance
# 4985  furniture/equipment        100<=X<500     guarantor                car
# 4986             radio/tv              <100     guarantor  no known property
# 4987             radio/tv        100<=X<500  co applicant     life insurance
# 4988           retraining  no known savings  co applicant  no known property
# 4989                other              <100          none                car
# 4990             radio/tv            >=1000  co applicant  no known property
# 4991              new car            >=1000          none                car
# 4992             used car            >=1000     guarantor  no known property
# 4993             radio/tv       500<=X<1000          none        real estate
# 4994              new car       500<=X<1000     guarantor                car
# 4995             radio/tv        100<=X<500  co applicant        real estate
# 4996                other  no known savings  co applicant  no known property
# 4997             business       500<=X<1000     guarantor  no known property
# 4998  furniture/equipment            >=1000  co applicant     life insurance
# 4999           retraining        100<=X<500  co applicant  no known property
#
#      other_payment_plans   housing                        job   ...    class  \
# 0                   none       own    unemp/unskilled non res   ...      bad
# 1                   none  for free    unemp/unskilled non res   ...      bad
# 2                   none  for free    unemp/unskilled non res   ...     good
# 3                 stores      rent         unskilled resident   ...     good
# 4                   none       own         unskilled resident   ...     good
# 5                   bank      rent    unemp/unskilled non res   ...     good
# 6                 stores      rent         unskilled resident   ...      bad
# 7                   none      rent         unskilled resident   ...     good
# 8                   none      rent                    skilled   ...      bad
# 9                 stores       own                    skilled   ...      bad
# 10                  none      rent         unskilled resident   ...      bad
# 11                  none      rent    unemp/unskilled non res   ...     good
# 12                  bank      rent  high qualif/self emp/mgmt   ...     good
# 13                stores       own         unskilled resident   ...     good
# 14                  bank      rent    unemp/unskilled non res   ...     good
# 15                stores      rent         unskilled resident   ...     good
# 16                stores      rent    unemp/unskilled non res   ...      bad
# 17                  bank       own    unemp/unskilled non res   ...      bad
# 18                  none      rent  high qualif/self emp/mgmt   ...     good
# 19                  bank  for free                    skilled   ...      bad
# 20                stores       own  high qualif/self emp/mgmt   ...      bad
# 21                  none  for free    unemp/unskilled non res   ...     good
# 22                  bank  for free         unskilled resident   ...     good
# 23                  bank       own         unskilled resident   ...      bad
# 24                stores       own         unskilled resident   ...      bad
# 25                  none       own  high qualif/self emp/mgmt   ...     good
# 26                  bank       own  high qualif/self emp/mgmt   ...     good
# 27                stores       own         unskilled resident   ...     good
# 28                  none      rent                    skilled   ...      bad
# 29                  none  for free  high qualif/self emp/mgmt   ...     good
# ...                  ...       ...                        ...   ...      ...
# 4970                none      rent    unemp/unskilled non res   ...      bad
# 4971                none       own    unemp/unskilled non res   ...      bad
# 4972                bank      rent                    skilled   ...     good
# 4973                bank  for free    unemp/unskilled non res   ...     good
# 4974                none       own    unemp/unskilled non res   ...      bad
# 4975                none  for free                    skilled   ...      bad
# 4976                bank  for free  high qualif/self emp/mgmt   ...     good
# 4977                none       own         unskilled resident   ...     good
# 4978                bank      rent         unskilled resident   ...      bad
# 4979                bank       own    unemp/unskilled non res   ...      bad
# 4980                bank       own  high qualif/self emp/mgmt   ...      bad
# 4981              stores       own                    skilled   ...     good
# 4982              stores  for free         unskilled resident   ...      bad
# 4983                none  for free                    skilled   ...     good
# 4984                bank       own                    skilled   ...     good
# 4985                bank      rent    unemp/unskilled non res   ...     good
# 4986                none       own  high qualif/self emp/mgmt   ...     good
# 4987                none       own         unskilled resident   ...     good
# 4988                bank  for free  high qualif/self emp/mgmt   ...     good
# 4989                none       own                    skilled   ...     good
# 4990              stores  for free                    skilled   ...      bad
# 4991                none       own  high qualif/self emp/mgmt   ...      bad
# 4992                bank      rent    unemp/unskilled non res   ...      bad
# 4993              stores      rent    unemp/unskilled non res   ...      bad
# 4994                none      rent  high qualif/self emp/mgmt   ...      bad
# 4995              stores       own  high qualif/self emp/mgmt   ...      bad
# 4996              stores      rent    unemp/unskilled non res   ...     good
# 4997              stores      rent  high qualif/self emp/mgmt   ...      bad
# 4998                bank       own                    skilled   ...      bad
# 4999                none  for free         unskilled resident   ...      bad
#
#      installment_commitment residence_since  existing_credits  num_dependents  \
# 0                         4               2                 3               2
# 1                         2               2                 1               2
# 2                         1               1                 4               1
# 3                         3               1                 2               1
# 4                         2               1                 2               1
# 5                         1               3                 4               2
# 6                         1               3                 2               2
# 7                         3               3                 1               2
# 8                         1               4                 1               1
# 9                         4               1                 2               1
# 10                        4               3                 4               2
# 11                        1               4                 1               2
# 12                        4               1                 4               2
# 13                        4               3                 2               1
# 14                        4               1                 2               1
# 15                        2               1                 4               2
# 16                        2               4                 3               2
# 17                        1               4                 1               2
# 18                        2               1                 2               1
# 19                        3               1                 4               1
# 20                        3               4                 4               1
# 21                        3               3                 1               1
# 22                        4               4                 4               2
# 23                        4               1                 2               1
# 24                        4               2                 2               2
# 25                        2               3                 1               2
# 26                        1               3                 3               1
# 27                        1               2                 1               2
# 28                        2               3                 1               2
# 29                        3               1                 2               2
# ...                     ...             ...               ...             ...
# 4970                      1               1                 1               2
# 4971                      3               4                 1               2
# 4972                      3               4                 1               2
# 4973                      1               4                 3               2
# 4974                      3               3                 2               1
# 4975                      2               3                 1               1
# 4976                      3               2                 4               2
# 4977                      1               4                 1               1
# 4978                      4               2                 3               2
# 4979                      2               3                 3               2
# 4980                      4               1                 2               2
# 4981                      4               3                 1               2
# 4982                      3               1                 3               1
# 4983                      2               4                 3               1
# 4984                      4               2                 3               1
# 4985                      1               2                 1               1
# 4986                      2               4                 4               1
# 4987                      1               1                 1               2
# 4988                      1               4                 4               2
# 4989                      1               2                 1               1
# 4990                      2               2                 1               2
# 4991                      4               1                 1               2
# 4992                      4               1                 3               2
# 4993                      1               2                 4               2
# 4994                      1               2                 2               1
# 4995                      3               3                 3               1
# 4996                      1               2                 1               1
# 4997                      1               2                 4               1
# 4998                      3               1                 2               2
# 4999                      3               1                 2               2
#
#       checking_status  duration credit_amount  employment      age
# 0         no checking       x<4         x<250      1<=X<4     x<19
# 1                  <0   38<x<55       x>13880         >=7  19<x<33
# 2                  <0   38<x<55  9337<x<13880      4<=X<7  33<x<47
# 3                  <0      x>55    250<x<4793          <1  33<x<47
# 4            0<=X<200       x<4   4793<x<9337      4<=X<7     x>61
# 5                  <0   21<x<38    250<x<4793          <1  33<x<47
# 6                  <0    4<x<21         x<250      1<=X<4  33<x<47
# 7         no checking    4<x<21       x>13880  unemployed  33<x<47
# 8                  <0       x<4  9337<x<13880          <1  19<x<33
# 9            0<=X<200   38<x<55       x>13880      4<=X<7     x<19
# 10           0<=X<200   21<x<38    250<x<4793      4<=X<7  47<x<61
# 11        no checking   38<x<55         x<250      4<=X<7     x<19
# 12              >=200   21<x<38         x<250          <1  33<x<47
# 13                 <0    4<x<21  9337<x<13880  unemployed  19<x<33
# 14           0<=X<200      x>55    250<x<4793      4<=X<7  33<x<47
# 15              >=200   21<x<38   4793<x<9337      1<=X<4     x>61
# 16                 <0       x<4       x>13880         >=7     x>61
# 17        no checking    4<x<21         x<250         >=7     x<19
# 18           0<=X<200   21<x<38   4793<x<9337          <1  47<x<61
# 19              >=200       x<4  9337<x<13880      1<=X<4  33<x<47
# 20        no checking      x>55       x>13880          <1  19<x<33
# 21              >=200    4<x<21    250<x<4793      4<=X<7  47<x<61
# 22           0<=X<200      x>55   4793<x<9337  unemployed     x>61
# 23        no checking    4<x<21       x>13880      1<=X<4     x<19
# 24           0<=X<200   38<x<55   4793<x<9337  unemployed     x<19
# 25           0<=X<200   38<x<55    250<x<4793      1<=X<4  33<x<47
# 26        no checking      x>55  9337<x<13880      4<=X<7  47<x<61
# 27                 <0      x>55    250<x<4793          <1  33<x<47
# 28           0<=X<200      x>55  9337<x<13880      4<=X<7     x<19
# 29        no checking       x<4   4793<x<9337  unemployed     x>61
# ...               ...       ...           ...         ...      ...
# 4970         0<=X<200      x>55    250<x<4793      1<=X<4     x<19
# 4971            >=200   21<x<38  9337<x<13880  unemployed  19<x<33
# 4972               <0   21<x<38  9337<x<13880      1<=X<4  33<x<47
# 4973      no checking    4<x<21    250<x<4793      4<=X<7  19<x<33
# 4974         0<=X<200       x<4         x<250      4<=X<7  47<x<61
# 4975            >=200   38<x<55  9337<x<13880          <1  19<x<33
# 4976            >=200   21<x<38  9337<x<13880          <1  47<x<61
# 4977            >=200    4<x<21       x>13880      4<=X<7     x<19
# 4978         0<=X<200    4<x<21  9337<x<13880          <1  47<x<61
# 4979            >=200    4<x<21   4793<x<9337      4<=X<7     x<19
# 4980      no checking      x>55    250<x<4793          <1  33<x<47
# 4981               <0       x<4   4793<x<9337         >=7     x<19
# 4982         0<=X<200      x>55  9337<x<13880  unemployed  33<x<47
# 4983            >=200      x>55       x>13880  unemployed     x<19
# 4984               <0   38<x<55   4793<x<9337          <1     x<19
# 4985               <0      x>55       x>13880      4<=X<7  19<x<33
# 4986               <0   21<x<38         x<250          <1     x>61
# 4987            >=200       x<4   4793<x<9337      1<=X<4     x<19
# 4988      no checking       x<4   4793<x<9337      1<=X<4  19<x<33
# 4989      no checking      x>55         x<250  unemployed  33<x<47
# 4990         0<=X<200    4<x<21    250<x<4793          <1  19<x<33
# 4991               <0   21<x<38         x<250          <1     x>61
# 4992         0<=X<200      x>55    250<x<4793          <1     x>61
# 4993         0<=X<200      x>55   4793<x<9337         >=7     x>61
# 4994               <0   21<x<38         x<250      1<=X<4  19<x<33
# 4995               <0   38<x<55   4793<x<9337      4<=X<7     x>61
# 4996               <0      x>55         x<250      4<=X<7  33<x<47
# 4997            >=200    4<x<21       x>13880         >=7  19<x<33
# 4998      no checking   21<x<38  9337<x<13880         >=7  19<x<33
# 4999      no checking   21<x<38       x>13880          <1     x>61
#
# [5000 rows x 22 columns]
